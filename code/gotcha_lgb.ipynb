# %%
import os

os.environ['NUM_OMP_THREADS'] = "4"

import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import lightgbm as lgb
import time
from sklearn.linear_model import HuberRegressor
import sklearn.ensemble as tree_model
from tqdm import tqdm
import datetime
pd.set_option('display.max_column',100)
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2
from utils import make_dir, score, timer, kf_lgbm, kf_xgbm, kf_ctbm, kf_sklearn

# %%
def make_features(df):
    app_feature = [
        '当月网购类应用使用次数',
        '当月物流快递类应用使用次数',
        '当月金融理财类应用使用总次数',
        '当月视频播放类应用使用次数',
        '当月飞机类应用使用次数',
        '当月火车类应用使用次数',
        '当月旅游资讯类应用使用次数',
    ]
    
    for f in app_feature:
        df['round_log1p'+f] = np.round(np.log1p(df[f])).astype(int)
    
    df['前五个月消费总费用'] = 6*df['用户近6个月平均消费值（元）'] - df['用户账单当月总费用（元）']
    df['前五个月消费平均费用'] = df['前五个月消费总费用'] / 5
    df['当月费用/前五个月消费平均费用'] = (df['用户账单当月总费用（元）']) \
                        / (1+df['前五个月消费平均费用'])
    df['当月费用-前五个月消费平均费用'] = df['用户账单当月总费用（元）'] - df['前五个月消费平均费用']
        
    def make_count_feature(df, col, fea_name):
        df['idx'] = range(len(df))
        tmp = df.groupby(col)['用户编码'].agg([
            (fea_name,'count')]).reset_index()
        df = df.merge(tmp)
        df = df.sort_values('idx').drop('idx',axis=1).reset_index(drop=True)
        return df
        
    df = make_count_feature(df, '缴费用户最近一次缴费金额（元）','count_缴费')
    df = make_count_feature(df, '用户账单当月总费用（元）','count_当月费用')
    df = make_count_feature(df, '前五个月消费总费用', 'count_总费用')
    df = make_count_feature(df, '当月费用-前五个月消费平均费用', 'count_费用差')
    df = make_count_feature(df, '用户近6个月平均消费值（元）', 'count_平均费用')
    df = make_count_feature(df, ['用户账单当月总费用（元）','用户近6个月平均消费值（元）'],
                            'count_当月费用_平均费用')
            
    arr = df['缴费用户最近一次缴费金额（元）']
    df['是否998折'] = ((arr/0.998)%1==0)&(arr!=0)
    
    df['年龄_0_as_nan'] = np.where(df['用户年龄']==0, [np.nan]*len(df), df['用户年龄'])
    
    return df
    
def load_df_and_make_features():
    train_df = pd.read_csv('../input/train_dataset.csv')
    test_df = pd.read_csv('../input/test_dataset.csv')
    train_df['train'] = 1
    test_df['train'] = 0
    df = pd.concat([train_df,test_df])
    df = make_features(df)
    return df

# %%
feature_name1 = \
['用户年龄',
 '用户网龄（月）',
 '用户实名制是否通过核实',
 '是否大学生客户',
 '是否4G不健康客户',
 '用户最近一次缴费距今时长（月）',
 '缴费用户最近一次缴费金额（元）',
 '用户近6个月平均消费值（元）',
 '用户账单当月总费用（元）',
 '用户当月账户余额（元）',
 '用户话费敏感度',
 '当月费用-前五个月消费平均费用',
 '前五个月消费总费用',
 'count_缴费',
 'count_当月费用',
 'count_费用差',
 'count_平均费用',
 'count_当月费用_平均费用',
 '是否998折',
 '当月通话交往圈人数',
 '近三个月月均商场出现次数',
 '当月网购类应用使用次数',
 '当月物流快递类应用使用次数',
 '当月金融理财类应用使用总次数',
 '当月视频播放类应用使用次数',
 '当月飞机类应用使用次数',
 '当月火车类应用使用次数',
 '当月旅游资讯类应用使用次数',
 '当月是否逛过福州仓山万达',
 '当月是否到过福州山姆会员店',
 '当月是否看电影',
 '当月是否景点游览',
 '当月是否体育场馆消费',
 '是否经常逛商场的人',
 '是否黑名单客户',
 '缴费用户当前是否欠费缴费']


feature_name2 = \
['年龄_0_as_nan',
 '用户网龄（月）',
 '用户实名制是否通过核实',
 '是否大学生客户',
 '是否4G不健康客户',
 '用户最近一次缴费距今时长（月）',
 '缴费用户最近一次缴费金额（元）',
 '用户近6个月平均消费值（元）',
 '用户账单当月总费用（元）',
 '用户当月账户余额（元）',
 '用户话费敏感度',
 '当月费用-前五个月消费平均费用',
 '前五个月消费总费用',
 'count_缴费',
 'count_当月费用',
 'count_费用差',
 'count_平均费用',
 'count_当月费用_平均费用',
 '是否998折',
 '当月通话交往圈人数',
 '近三个月月均商场出现次数',
 '当月网购类应用使用次数',
 '当月物流快递类应用使用次数',
 '当月金融理财类应用使用总次数',
 '当月视频播放类应用使用次数',
 '当月飞机类应用使用次数',
 '当月火车类应用使用次数',
 '当月旅游资讯类应用使用次数',
 '当月是否逛过福州仓山万达',
 '当月是否到过福州山姆会员店',
 '当月是否看电影',
 '当月是否景点游览',
 '当月是否体育场馆消费',
 '是否经常逛商场的人',
 '是否黑名单客户',
 '缴费用户当前是否欠费缴费']

feature_name3 = \
['用户年龄',
 '用户网龄（月）',
 '用户实名制是否通过核实',
 '是否大学生客户',
 '是否4G不健康客户',
 '用户最近一次缴费距今时长（月）',
 '缴费用户最近一次缴费金额（元）',
 '用户近6个月平均消费值（元）',
 '用户账单当月总费用（元）',
 '用户当月账户余额（元）',
 '用户话费敏感度',
 '当月费用-前五个月消费平均费用',
 '前五个月消费总费用',
 'count_缴费',
 'count_当月费用',
 'count_费用差',
 'count_平均费用',
 'count_当月费用_平均费用',
 '是否998折',
 '当月通话交往圈人数',
 '近三个月月均商场出现次数',
 'round_log1p当月网购类应用使用次数',
 'round_log1p当月物流快递类应用使用次数',
 'round_log1p当月金融理财类应用使用总次数',
 'round_log1p当月视频播放类应用使用次数',
 'round_log1p当月飞机类应用使用次数',
 'round_log1p当月火车类应用使用次数',
 'round_log1p当月旅游资讯类应用使用次数',
 '当月是否逛过福州仓山万达',
 '当月是否到过福州山姆会员店',
 '当月是否看电影',
 '当月是否景点游览',
 '当月是否体育场馆消费',
 '是否经常逛商场的人',
 '是否黑名单客户',
 '缴费用户当前是否欠费缴费']

feature_name4 = \
['年龄_0_as_nan',
 '用户网龄（月）',
 '用户实名制是否通过核实',
 '是否大学生客户',
 '是否4G不健康客户',
 '用户最近一次缴费距今时长（月）',
 '缴费用户最近一次缴费金额（元）',
 '用户近6个月平均消费值（元）',
 '用户账单当月总费用（元）',
 '用户当月账户余额（元）',
 '用户话费敏感度',
 '当月费用-前五个月消费平均费用',
 '前五个月消费总费用',
 'count_缴费',
 'count_当月费用',
 'count_费用差',
 'count_平均费用',
 'count_当月费用_平均费用',
 '是否998折',
 '当月通话交往圈人数',
 '近三个月月均商场出现次数',
 'round_log1p当月网购类应用使用次数',
 'round_log1p当月物流快递类应用使用次数',
 'round_log1p当月金融理财类应用使用总次数',
 'round_log1p当月视频播放类应用使用次数',
 'round_log1p当月飞机类应用使用次数',
 'round_log1p当月火车类应用使用次数',
 'round_log1p当月旅游资讯类应用使用次数',
 '当月是否逛过福州仓山万达',
 '当月是否到过福州山姆会员店',
 '当月是否看电影',
 '当月是否景点游览',
 '当月是否体育场馆消费',
 '是否经常逛商场的人',
 '是否黑名单客户',
 '缴费用户当前是否欠费缴费']

feature_name5 = \
['用户年龄',
 '用户网龄（月）',
 '用户实名制是否通过核实',
 '是否大学生客户',
 '是否4G不健康客户',
 '用户最近一次缴费距今时长（月）',
 '缴费用户最近一次缴费金额（元）',
 '用户近6个月平均消费值（元）',
 '用户账单当月总费用（元）',
 '用户当月账户余额（元）',
 '用户话费敏感度',
 '当月费用-前五个月消费平均费用',
 '当月通话交往圈人数',
 '近三个月月均商场出现次数',
 '当月网购类应用使用次数',
 '当月物流快递类应用使用次数',
 '当月金融理财类应用使用总次数',
 '当月视频播放类应用使用次数',
 '当月飞机类应用使用次数',
 '当月火车类应用使用次数',
 '当月旅游资讯类应用使用次数',
 '当月是否逛过福州仓山万达',
 '当月是否到过福州山姆会员店',
 '当月是否看电影',
 '当月是否景点游览',
 '当月是否体育场馆消费',
 '是否经常逛商场的人',
 '是否黑名单客户',
 '缴费用户当前是否欠费缴费']


feature_name6 = \
['年龄_0_as_nan',
 '用户网龄（月）',
 '用户实名制是否通过核实',
 '是否大学生客户',
 '是否4G不健康客户',
 '用户最近一次缴费距今时长（月）',
 '缴费用户最近一次缴费金额（元）',
 '用户近6个月平均消费值（元）',
 '用户账单当月总费用（元）',
 '用户当月账户余额（元）',
 '用户话费敏感度',
 '当月费用-前五个月消费平均费用',
 '当月通话交往圈人数',
 '近三个月月均商场出现次数',
 '当月网购类应用使用次数',
 '当月物流快递类应用使用次数',
 '当月金融理财类应用使用总次数',
 '当月视频播放类应用使用次数',
 '当月飞机类应用使用次数',
 '当月火车类应用使用次数',
 '当月旅游资讯类应用使用次数',
 '当月是否逛过福州仓山万达',
 '当月是否到过福州山姆会员店',
 '当月是否看电影',
 '当月是否景点游览',
 '当月是否体育场馆消费',
 '是否经常逛商场的人',
 '是否黑名单客户',
 '缴费用户当前是否欠费缴费']

# %%
df = load_df_and_make_features()
train_df = df[df['train']==1]
test_df = df[df['train']!=1]

# %%
# now = str(datetime.datetime.now()).split('.')[0]
# now=now.replace(' ','_')
# now=now.replace(':','-')
# output_dir = 'lgb'+now
output_dir = './stacking_files/'

# %%
x, y = train_df[feature_name1], train_df['信用分'].values
x_test = test_df[feature_name1]

model = kf_lgbm(x=x,y=y,x_test=x_test,learning_rate=0.01, 
                stratify=True,
                min_split_gain=1,
                categorical_feature=['用户话费敏感度'],
                boosting_type='gbdt',
                early_stopping_rounds=80,
                fair_c=25, 
                huber_delta=2,
                max_cat_to_onehot=4,
                objective="mae_fair",
                eval_metric="mae",
                subsample_freq=2,
                min_child_samples=20,
                num_leaves=31,
                bagging_fraction=0.8,
                feature_fraction=0.5,
                max_depth=5,
                output_dir=output_dir,
                name='gotcha_lgb1',
                n_estimators=8000)
# Out:
# ================================================== Fold 1 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6015	train's mae: 15.6015	test's l1: 15.8681	test's mae: 15.8681
# [400]	train's l1: 14.6312	train's mae: 14.6312	test's l1: 15.0797	test's mae: 15.0797
# [600]	train's l1: 14.3699	train's mae: 14.3699	test's l1: 14.9224	test's mae: 14.9224
# [800]	train's l1: 14.2164	train's mae: 14.2164	test's l1: 14.8466	test's mae: 14.8466
# [1000]	train's l1: 14.0943	train's mae: 14.0943	test's l1: 14.8012	test's mae: 14.8012
# [1200]	train's l1: 13.986	train's mae: 13.986	test's l1: 14.7672	test's mae: 14.7672
# [1400]	train's l1: 13.8829	train's mae: 13.8829	test's l1: 14.7333	test's mae: 14.7333
# [1600]	train's l1: 13.7907	train's mae: 13.7907	test's l1: 14.7107	test's mae: 14.7107
# [1800]	train's l1: 13.7037	train's mae: 13.7037	test's l1: 14.6936	test's mae: 14.6936
# [2000]	train's l1: 13.6225	train's mae: 13.6225	test's l1: 14.6796	test's mae: 14.6796
# [2200]	train's l1: 13.54	train's mae: 13.54	test's l1: 14.6659	test's mae: 14.6659
# [2400]	train's l1: 13.4648	train's mae: 13.4648	test's l1: 14.6515	test's mae: 14.6515
# [2600]	train's l1: 13.3926	train's mae: 13.3926	test's l1: 14.6392	test's mae: 14.6392
# [2800]	train's l1: 13.3236	train's mae: 13.3236	test's l1: 14.63	test's mae: 14.63
# [3000]	train's l1: 13.2526	train's mae: 13.2526	test's l1: 14.6217	test's mae: 14.6217
# [3200]	train's l1: 13.1863	train's mae: 13.1863	test's l1: 14.6176	test's mae: 14.6176
# [3400]	train's l1: 13.1194	train's mae: 13.1194	test's l1: 14.6158	test's mae: 14.6158
# Early stopping, best iteration is:
# [3338]	train's l1: 13.1424	train's mae: 13.1424	test's l1: 14.6147	test's mae: 14.6147
#
# ================================================== Fold 2 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.615	train's mae: 15.615	test's l1: 15.8096	test's mae: 15.8096
# [400]	train's l1: 14.6538	train's mae: 14.6538	test's l1: 14.8987	test's mae: 14.8987
# [600]	train's l1: 14.389	train's mae: 14.389	test's l1: 14.7119	test's mae: 14.7119
# [800]	train's l1: 14.2405	train's mae: 14.2405	test's l1: 14.6308	test's mae: 14.6308
# [1000]	train's l1: 14.1148	train's mae: 14.1148	test's l1: 14.5834	test's mae: 14.5834
# [1200]	train's l1: 14.0112	train's mae: 14.0112	test's l1: 14.555	test's mae: 14.555
# [1400]	train's l1: 13.9148	train's mae: 13.9148	test's l1: 14.5329	test's mae: 14.5329
# [1600]	train's l1: 13.8236	train's mae: 13.8236	test's l1: 14.5145	test's mae: 14.5145
# [1800]	train's l1: 13.7358	train's mae: 13.7358	test's l1: 14.4987	test's mae: 14.4987
# [2000]	train's l1: 13.6502	train's mae: 13.6502	test's l1: 14.4903	test's mae: 14.4903
# [2200]	train's l1: 13.5654	train's mae: 13.5654	test's l1: 14.4839	test's mae: 14.4839
# [2400]	train's l1: 13.4913	train's mae: 13.4913	test's l1: 14.4759	test's mae: 14.4759
# [2600]	train's l1: 13.4163	train's mae: 13.4163	test's l1: 14.4708	test's mae: 14.4708
# [2800]	train's l1: 13.3446	train's mae: 13.3446	test's l1: 14.4674	test's mae: 14.4674
# [3000]	train's l1: 13.2715	train's mae: 13.2715	test's l1: 14.4624	test's mae: 14.4624
# Early stopping, best iteration is:
# [2996]	train's l1: 13.2726	train's mae: 13.2726	test's l1: 14.4621	test's mae: 14.4621
#
# ================================================== Fold 3 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6203	train's mae: 15.6203	test's l1: 15.6506	test's mae: 15.6506
# [400]	train's l1: 14.6508	train's mae: 14.6508	test's l1: 14.8238	test's mae: 14.8238
# [600]	train's l1: 14.3926	train's mae: 14.3926	test's l1: 14.6748	test's mae: 14.6748
# [800]	train's l1: 14.2324	train's mae: 14.2324	test's l1: 14.6041	test's mae: 14.6041
# [1000]	train's l1: 14.108	train's mae: 14.108	test's l1: 14.5669	test's mae: 14.5669
# [1200]	train's l1: 14.002	train's mae: 14.002	test's l1: 14.5403	test's mae: 14.5403
# [1400]	train's l1: 13.902	train's mae: 13.902	test's l1: 14.5187	test's mae: 14.5187
# [1600]	train's l1: 13.8083	train's mae: 13.8083	test's l1: 14.502	test's mae: 14.502
# [1800]	train's l1: 13.7189	train's mae: 13.7189	test's l1: 14.4892	test's mae: 14.4892
# [2000]	train's l1: 13.636	train's mae: 13.636	test's l1: 14.4772	test's mae: 14.4772
# [2200]	train's l1: 13.5574	train's mae: 13.5574	test's l1: 14.4706	test's mae: 14.4706
# [2400]	train's l1: 13.4775	train's mae: 13.4775	test's l1: 14.4672	test's mae: 14.4672
# Early stopping, best iteration is:
# [2470]	train's l1: 13.4506	train's mae: 13.4506	test's l1: 14.4654	test's mae: 14.4654
#
# ================================================== Fold 4 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.5872	train's mae: 15.5872	test's l1: 16.0068	test's mae: 16.0068
# [400]	train's l1: 14.6245	train's mae: 14.6245	test's l1: 15.162	test's mae: 15.162
# [600]	train's l1: 14.3574	train's mae: 14.3574	test's l1: 14.9987	test's mae: 14.9987
# [800]	train's l1: 14.209	train's mae: 14.209	test's l1: 14.9439	test's mae: 14.9439
# [1000]	train's l1: 14.0869	train's mae: 14.0869	test's l1: 14.9066	test's mae: 14.9066
# [1200]	train's l1: 13.9798	train's mae: 13.9798	test's l1: 14.8774	test's mae: 14.8774
# [1400]	train's l1: 13.8835	train's mae: 13.8835	test's l1: 14.8541	test's mae: 14.8541
# [1600]	train's l1: 13.7885	train's mae: 13.7885	test's l1: 14.8317	test's mae: 14.8317
# [1800]	train's l1: 13.7001	train's mae: 13.7001	test's l1: 14.8147	test's mae: 14.8147
# [2000]	train's l1: 13.6181	train's mae: 13.6181	test's l1: 14.8012	test's mae: 14.8012
# [2200]	train's l1: 13.5368	train's mae: 13.5368	test's l1: 14.7911	test's mae: 14.7911
# [2400]	train's l1: 13.4584	train's mae: 13.4584	test's l1: 14.7851	test's mae: 14.7851
# [2600]	train's l1: 13.3824	train's mae: 13.3824	test's l1: 14.7788	test's mae: 14.7788
# [2800]	train's l1: 13.3111	train's mae: 13.3111	test's l1: 14.7751	test's mae: 14.7751
# [3000]	train's l1: 13.2393	train's mae: 13.2393	test's l1: 14.7696	test's mae: 14.7696
# Early stopping, best iteration is:
# [3046]	train's l1: 13.2231	train's mae: 13.2231	test's l1: 14.7676	test's mae: 14.7676
#
# ================================================== Fold 5 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6139	train's mae: 15.6139	test's l1: 15.743	test's mae: 15.743
# [400]	train's l1: 14.6474	train's mae: 14.6474	test's l1: 14.8847	test's mae: 14.8847
# [600]	train's l1: 14.383	train's mae: 14.383	test's l1: 14.7017	test's mae: 14.7017
# [800]	train's l1: 14.2364	train's mae: 14.2364	test's l1: 14.6203	test's mae: 14.6203
# [1000]	train's l1: 14.1142	train's mae: 14.1142	test's l1: 14.5726	test's mae: 14.5726
# [1200]	train's l1: 14.0071	train's mae: 14.0071	test's l1: 14.54	test's mae: 14.54
# [1400]	train's l1: 13.9064	train's mae: 13.9064	test's l1: 14.5149	test's mae: 14.5149
# [1600]	train's l1: 13.8156	train's mae: 13.8156	test's l1: 14.493	test's mae: 14.493
# [1800]	train's l1: 13.7249	train's mae: 13.7249	test's l1: 14.4771	test's mae: 14.4771
# [2000]	train's l1: 13.6423	train's mae: 13.6423	test's l1: 14.4678	test's mae: 14.4678
# [2200]	train's l1: 13.5602	train's mae: 13.5602	test's l1: 14.4605	test's mae: 14.4605
# [2400]	train's l1: 13.4854	train's mae: 13.4854	test's l1: 14.4507	test's mae: 14.4507
# [2600]	train's l1: 13.4084	train's mae: 13.4084	test's l1: 14.4487	test's mae: 14.4487
# [2800]	train's l1: 13.3401	train's mae: 13.3401	test's l1: 14.4434	test's mae: 14.4434
# [3000]	train's l1: 13.2667	train's mae: 13.2667	test's l1: 14.4393	test's mae: 14.4393
# Early stopping, best iteration is:
# [2932]	train's l1: 13.2905	train's mae: 13.2905	test's l1: 14.4389	test's mae: 14.4389
#
# ================================================== Fold 6 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.5991	train's mae: 15.5991	test's l1: 15.9278	test's mae: 15.9278
# [400]	train's l1: 14.6326	train's mae: 14.6326	test's l1: 15.1055	test's mae: 15.1055
# [600]	train's l1: 14.3718	train's mae: 14.3718	test's l1: 14.9456	test's mae: 14.9456
# [800]	train's l1: 14.2181	train's mae: 14.2181	test's l1: 14.8683	test's mae: 14.8683
# [1000]	train's l1: 14.0974	train's mae: 14.0974	test's l1: 14.8189	test's mae: 14.8189
# [1200]	train's l1: 13.9849	train's mae: 13.9849	test's l1: 14.7766	test's mae: 14.7766
# [1400]	train's l1: 13.8855	train's mae: 13.8855	test's l1: 14.7543	test's mae: 14.7543
# [1600]	train's l1: 13.7919	train's mae: 13.7919	test's l1: 14.735	test's mae: 14.735
# [1800]	train's l1: 13.7023	train's mae: 13.7023	test's l1: 14.7245	test's mae: 14.7245
# [2000]	train's l1: 13.6181	train's mae: 13.6181	test's l1: 14.7149	test's mae: 14.7149
# [2200]	train's l1: 13.5362	train's mae: 13.5362	test's l1: 14.7088	test's mae: 14.7088
# [2400]	train's l1: 13.4585	train's mae: 13.4585	test's l1: 14.7046	test's mae: 14.7046
# [2600]	train's l1: 13.3836	train's mae: 13.3836	test's l1: 14.6986	test's mae: 14.6986
# [2800]	train's l1: 13.3112	train's mae: 13.3112	test's l1: 14.6954	test's mae: 14.6954
# Early stopping, best iteration is:
# [2863]	train's l1: 13.287	train's mae: 13.287	test's l1: 14.6936	test's mae: 14.6936
#
# ================================================== Fold 7 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.5854	train's mae: 15.5854	test's l1: 16.0071	test's mae: 16.0071
# [400]	train's l1: 14.6244	train's mae: 14.6244	test's l1: 15.148	test's mae: 15.148
# [600]	train's l1: 14.3612	train's mae: 14.3612	test's l1: 14.9858	test's mae: 14.9858
# [800]	train's l1: 14.2051	train's mae: 14.2051	test's l1: 14.9244	test's mae: 14.9244
# [1000]	train's l1: 14.0851	train's mae: 14.0851	test's l1: 14.8949	test's mae: 14.8949
# [1200]	train's l1: 13.973	train's mae: 13.973	test's l1: 14.8708	test's mae: 14.8708
# [1400]	train's l1: 13.8747	train's mae: 13.8747	test's l1: 14.8583	test's mae: 14.8583
# [1600]	train's l1: 13.7815	train's mae: 13.7815	test's l1: 14.8435	test's mae: 14.8435
# [1800]	train's l1: 13.691	train's mae: 13.691	test's l1: 14.8316	test's mae: 14.8316
# [2000]	train's l1: 13.6036	train's mae: 13.6036	test's l1: 14.8238	test's mae: 14.8238
# [2200]	train's l1: 13.5218	train's mae: 13.5218	test's l1: 14.8198	test's mae: 14.8198
# [2400]	train's l1: 13.4446	train's mae: 13.4446	test's l1: 14.8133	test's mae: 14.8133
# Early stopping, best iteration is:
# [2500]	train's l1: 13.4052	train's mae: 13.4052	test's l1: 14.8116	test's mae: 14.8116
#
# ================================================== Fold 8 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6106	train's mae: 15.6106	test's l1: 15.7015	test's mae: 15.7015
# [400]	train's l1: 14.6527	train's mae: 14.6527	test's l1: 14.9109	test's mae: 14.9109
# [600]	train's l1: 14.3888	train's mae: 14.3888	test's l1: 14.7461	test's mae: 14.7461
# [800]	train's l1: 14.2329	train's mae: 14.2329	test's l1: 14.684	test's mae: 14.684
# [1000]	train's l1: 14.1101	train's mae: 14.1101	test's l1: 14.6404	test's mae: 14.6404
# [1200]	train's l1: 14.0005	train's mae: 14.0005	test's l1: 14.6121	test's mae: 14.6121
# [1400]	train's l1: 13.9052	train's mae: 13.9052	test's l1: 14.5949	test's mae: 14.5949
# [1600]	train's l1: 13.8126	train's mae: 13.8126	test's l1: 14.5809	test's mae: 14.5809
# [1800]	train's l1: 13.7218	train's mae: 13.7218	test's l1: 14.5701	test's mae: 14.5701
# [2000]	train's l1: 13.6365	train's mae: 13.6365	test's l1: 14.5573	test's mae: 14.5573
# [2200]	train's l1: 13.5542	train's mae: 13.5542	test's l1: 14.5514	test's mae: 14.5514
# [2400]	train's l1: 13.4767	train's mae: 13.4767	test's l1: 14.5436	test's mae: 14.5436
# [2600]	train's l1: 13.3983	train's mae: 13.3983	test's l1: 14.5379	test's mae: 14.5379
# [2800]	train's l1: 13.3264	train's mae: 13.3264	test's l1: 14.5318	test's mae: 14.5318
# Early stopping, best iteration is:
# [2828]	train's l1: 13.3166	train's mae: 13.3166	test's l1: 14.5311	test's mae: 14.5311
#
# ================================================== Fold 9 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.5956	train's mae: 15.5956	test's l1: 15.9266	test's mae: 15.9266
# [400]	train's l1: 14.6304	train's mae: 14.6304	test's l1: 15.044	test's mae: 15.044
# [600]	train's l1: 14.3747	train's mae: 14.3747	test's l1: 14.8724	test's mae: 14.8724
# [800]	train's l1: 14.2202	train's mae: 14.2202	test's l1: 14.8048	test's mae: 14.8048
# [1000]	train's l1: 14.1032	train's mae: 14.1032	test's l1: 14.7648	test's mae: 14.7648
# [1200]	train's l1: 13.9939	train's mae: 13.9939	test's l1: 14.7299	test's mae: 14.7299
# [1400]	train's l1: 13.8976	train's mae: 13.8976	test's l1: 14.7041	test's mae: 14.7041
# [1600]	train's l1: 13.8084	train's mae: 13.8084	test's l1: 14.6879	test's mae: 14.6879
# [1800]	train's l1: 13.7175	train's mae: 13.7175	test's l1: 14.6663	test's mae: 14.6663
# [2000]	train's l1: 13.6323	train's mae: 13.6323	test's l1: 14.6508	test's mae: 14.6508
# [2200]	train's l1: 13.5509	train's mae: 13.5509	test's l1: 14.6423	test's mae: 14.6423
# [2400]	train's l1: 13.4745	train's mae: 13.4745	test's l1: 14.6359	test's mae: 14.6359
# [2600]	train's l1: 13.3988	train's mae: 13.3988	test's l1: 14.6295	test's mae: 14.6295
# [2800]	train's l1: 13.3241	train's mae: 13.3241	test's l1: 14.6204	test's mae: 14.6204
# [3000]	train's l1: 13.2542	train's mae: 13.2542	test's l1: 14.6152	test's mae: 14.6152
# [3200]	train's l1: 13.1846	train's mae: 13.1846	test's l1: 14.6063	test's mae: 14.6063
# [3400]	train's l1: 13.1163	train's mae: 13.1163	test's l1: 14.6048	test's mae: 14.6048
# Early stopping, best iteration is:
# [3480]	train's l1: 13.0871	train's mae: 13.0871	test's l1: 14.6034	test's mae: 14.6034
#
# ================================================== Fold 10 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.618	train's mae: 15.618	test's l1: 15.6813	test's mae: 15.6813
# [400]	train's l1: 14.6605	train's mae: 14.6605	test's l1: 14.8116	test's mae: 14.8116
# [600]	train's l1: 14.4	train's mae: 14.4	test's l1: 14.6153	test's mae: 14.6153
# [800]	train's l1: 14.2487	train's mae: 14.2487	test's l1: 14.5242	test's mae: 14.5242
# [1000]	train's l1: 14.1243	train's mae: 14.1243	test's l1: 14.4676	test's mae: 14.4676
# [1200]	train's l1: 14.0177	train's mae: 14.0177	test's l1: 14.4334	test's mae: 14.4334
# [1400]	train's l1: 13.9218	train's mae: 13.9218	test's l1: 14.4079	test's mae: 14.4079
# [1600]	train's l1: 13.8302	train's mae: 13.8302	test's l1: 14.3891	test's mae: 14.3891
# [1800]	train's l1: 13.7451	train's mae: 13.7451	test's l1: 14.3766	test's mae: 14.3766
# [2000]	train's l1: 13.666	train's mae: 13.666	test's l1: 14.3684	test's mae: 14.3684
# [2200]	train's l1: 13.5843	train's mae: 13.5843	test's l1: 14.3588	test's mae: 14.3588
# Early stopping, best iteration is:
# [2265]	train's l1: 13.5591	train's mae: 13.5591	test's l1: 14.3563	test's mae: 14.3563
# ====================================================================================================
# 0.0640421125284779	0.06467441526539908	0.06466066726259555	0.06342101759620569	0.06477166039888313	0.06372039364834593	0.06324469863113852	0.06438702762452668	0.06408863674595722	0.06511974454926328
# min score: 0.063245
# max score: 0.065120
# median score: 0.064238
# mean score: 0.064213
# [601.59047979 523.72511041 669.83611465 675.78675833 657.47804232
#  614.05838897 640.49178199 570.44334371 674.26397909 590.26845798]

# %%
x, y = train_df[feature_name2], train_df['信用分'].values
x_test = test_df[feature_name2]

model = kf_lgbm(x=x,y=y,x_test=x_test,learning_rate=0.01, 
                stratify=True,
                min_split_gain=1,
                categorical_feature=['用户话费敏感度'],
                boosting_type='gbdt',
                early_stopping_rounds=80,
                fair_c=23, 
                huber_delta=2,
                max_cat_to_onehot=4,
                objective="fair_huber",
                eval_metric="mae",
                subsample_freq=2,
                min_child_samples=20,
                num_leaves=31,
                bagging_fraction=0.8,
                feature_fraction=0.5,
                max_depth=5,
                output_dir=output_dir,
                name='gotcha_lgb2',
                n_estimators=8000)
# Out:
# ================================================== Fold 1 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6963	train's mae: 15.6963	test's l1: 15.9533	test's mae: 15.9533
# [400]	train's l1: 14.6584	train's mae: 14.6584	test's l1: 15.0967	test's mae: 15.0967
# [600]	train's l1: 14.3789	train's mae: 14.3789	test's l1: 14.9297	test's mae: 14.9297
# [800]	train's l1: 14.2188	train's mae: 14.2188	test's l1: 14.8505	test's mae: 14.8505
# [1000]	train's l1: 14.0979	train's mae: 14.0979	test's l1: 14.8023	test's mae: 14.8023
# [1200]	train's l1: 13.993	train's mae: 13.993	test's l1: 14.7703	test's mae: 14.7703
# [1400]	train's l1: 13.895	train's mae: 13.895	test's l1: 14.7371	test's mae: 14.7371
# [1600]	train's l1: 13.8049	train's mae: 13.8049	test's l1: 14.7171	test's mae: 14.7171
# [1800]	train's l1: 13.7176	train's mae: 13.7176	test's l1: 14.6966	test's mae: 14.6966
# [2000]	train's l1: 13.6398	train's mae: 13.6398	test's l1: 14.6834	test's mae: 14.6834
# [2200]	train's l1: 13.5612	train's mae: 13.5612	test's l1: 14.6704	test's mae: 14.6704
# [2400]	train's l1: 13.4891	train's mae: 13.4891	test's l1: 14.6574	test's mae: 14.6574
# [2600]	train's l1: 13.4199	train's mae: 13.4199	test's l1: 14.6439	test's mae: 14.6439
# [2800]	train's l1: 13.3511	train's mae: 13.3511	test's l1: 14.6344	test's mae: 14.6344
# [3000]	train's l1: 13.2836	train's mae: 13.2836	test's l1: 14.6284	test's mae: 14.6284
# [3200]	train's l1: 13.2188	train's mae: 13.2188	test's l1: 14.6222	test's mae: 14.6222
# [3400]	train's l1: 13.1534	train's mae: 13.1534	test's l1: 14.6171	test's mae: 14.6171
# [3600]	train's l1: 13.0899	train's mae: 13.0899	test's l1: 14.6122	test's mae: 14.6122
# [3800]	train's l1: 13.0314	train's mae: 13.0314	test's l1: 14.6104	test's mae: 14.6104
# Early stopping, best iteration is:
# [3756]	train's l1: 13.044	train's mae: 13.044	test's l1: 14.6097	test's mae: 14.6097
#
# ================================================== Fold 2 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7031	train's mae: 15.7031	test's l1: 15.9205	test's mae: 15.9205
# [400]	train's l1: 14.6769	train's mae: 14.6769	test's l1: 14.9445	test's mae: 14.9445
# [600]	train's l1: 14.3924	train's mae: 14.3924	test's l1: 14.7381	test's mae: 14.7381
# [800]	train's l1: 14.2342	train's mae: 14.2342	test's l1: 14.6485	test's mae: 14.6485
# [1000]	train's l1: 14.1127	train's mae: 14.1127	test's l1: 14.5999	test's mae: 14.5999
# [1200]	train's l1: 14.0113	train's mae: 14.0113	test's l1: 14.5684	test's mae: 14.5684
# [1400]	train's l1: 13.9193	train's mae: 13.9193	test's l1: 14.547	test's mae: 14.547
# [1600]	train's l1: 13.8302	train's mae: 13.8302	test's l1: 14.5284	test's mae: 14.5284
# [1800]	train's l1: 13.7449	train's mae: 13.7449	test's l1: 14.5124	test's mae: 14.5124
# [2000]	train's l1: 13.6605	train's mae: 13.6605	test's l1: 14.504	test's mae: 14.504
# [2200]	train's l1: 13.5811	train's mae: 13.5811	test's l1: 14.4951	test's mae: 14.4951
# [2400]	train's l1: 13.51	train's mae: 13.51	test's l1: 14.4876	test's mae: 14.4876
# [2600]	train's l1: 13.437	train's mae: 13.437	test's l1: 14.4795	test's mae: 14.4795
# [2800]	train's l1: 13.3665	train's mae: 13.3665	test's l1: 14.4756	test's mae: 14.4756
# [3000]	train's l1: 13.2965	train's mae: 13.2965	test's l1: 14.4708	test's mae: 14.4708
# Early stopping, best iteration is:
# [2949]	train's l1: 13.3136	train's mae: 13.3136	test's l1: 14.4696	test's mae: 14.4696
#
# ================================================== Fold 3 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7176	train's mae: 15.7176	test's l1: 15.7307	test's mae: 15.7307
# [400]	train's l1: 14.6826	train's mae: 14.6826	test's l1: 14.8538	test's mae: 14.8538
# [600]	train's l1: 14.4044	train's mae: 14.4044	test's l1: 14.6944	test's mae: 14.6944
# [800]	train's l1: 14.242	train's mae: 14.242	test's l1: 14.6235	test's mae: 14.6235
# [1000]	train's l1: 14.1182	train's mae: 14.1182	test's l1: 14.5817	test's mae: 14.5817
# [1200]	train's l1: 14.015	train's mae: 14.015	test's l1: 14.5515	test's mae: 14.5515
# [1400]	train's l1: 13.9198	train's mae: 13.9198	test's l1: 14.5305	test's mae: 14.5305
# [1600]	train's l1: 13.8271	train's mae: 13.8271	test's l1: 14.5127	test's mae: 14.5127
# [1800]	train's l1: 13.742	train's mae: 13.742	test's l1: 14.5032	test's mae: 14.5032
# [2000]	train's l1: 13.6607	train's mae: 13.6607	test's l1: 14.4903	test's mae: 14.4903
# [2200]	train's l1: 13.5812	train's mae: 13.5812	test's l1: 14.4832	test's mae: 14.4832
# [2400]	train's l1: 13.5024	train's mae: 13.5024	test's l1: 14.4789	test's mae: 14.4789
# Early stopping, best iteration is:
# [2468]	train's l1: 13.4766	train's mae: 13.4766	test's l1: 14.4768	test's mae: 14.4768
#
# ================================================== Fold 4 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6794	train's mae: 15.6794	test's l1: 16.1011	test's mae: 16.1011
# [400]	train's l1: 14.6485	train's mae: 14.6485	test's l1: 15.1814	test's mae: 15.1814
# [600]	train's l1: 14.3647	train's mae: 14.3647	test's l1: 15.013	test's mae: 15.013
# [800]	train's l1: 14.2104	train's mae: 14.2104	test's l1: 14.9488	test's mae: 14.9488
# [1000]	train's l1: 14.0869	train's mae: 14.0869	test's l1: 14.913	test's mae: 14.913
# [1200]	train's l1: 13.9805	train's mae: 13.9805	test's l1: 14.8847	test's mae: 14.8847
# [1400]	train's l1: 13.8858	train's mae: 13.8858	test's l1: 14.8662	test's mae: 14.8662
# [1600]	train's l1: 13.7931	train's mae: 13.7931	test's l1: 14.846	test's mae: 14.846
# [1800]	train's l1: 13.7071	train's mae: 13.7071	test's l1: 14.8294	test's mae: 14.8294
# [2000]	train's l1: 13.6258	train's mae: 13.6258	test's l1: 14.8137	test's mae: 14.8137
# [2200]	train's l1: 13.5463	train's mae: 13.5463	test's l1: 14.8034	test's mae: 14.8034
# [2400]	train's l1: 13.4719	train's mae: 13.4719	test's l1: 14.7956	test's mae: 14.7956
# [2600]	train's l1: 13.4006	train's mae: 13.4006	test's l1: 14.7881	test's mae: 14.7881
# [2800]	train's l1: 13.3322	train's mae: 13.3322	test's l1: 14.7827	test's mae: 14.7827
# [3000]	train's l1: 13.2642	train's mae: 13.2642	test's l1: 14.7774	test's mae: 14.7774
# [3200]	train's l1: 13.1977	train's mae: 13.1977	test's l1: 14.7735	test's mae: 14.7735
# Early stopping, best iteration is:
# [3265]	train's l1: 13.1773	train's mae: 13.1773	test's l1: 14.7716	test's mae: 14.7716
#
# ================================================== Fold 5 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7023	train's mae: 15.7023	test's l1: 15.8418	test's mae: 15.8418
# [400]	train's l1: 14.6714	train's mae: 14.6714	test's l1: 14.9076	test's mae: 14.9076
# [600]	train's l1: 14.3937	train's mae: 14.3937	test's l1: 14.7153	test's mae: 14.7153
# [800]	train's l1: 14.2382	train's mae: 14.2382	test's l1: 14.6277	test's mae: 14.6277
# [1000]	train's l1: 14.1156	train's mae: 14.1156	test's l1: 14.5827	test's mae: 14.5827
# [1200]	train's l1: 14.0098	train's mae: 14.0098	test's l1: 14.549	test's mae: 14.549
# [1400]	train's l1: 13.913	train's mae: 13.913	test's l1: 14.5215	test's mae: 14.5215
# [1600]	train's l1: 13.8241	train's mae: 13.8241	test's l1: 14.5013	test's mae: 14.5013
# [1800]	train's l1: 13.7381	train's mae: 13.7381	test's l1: 14.4837	test's mae: 14.4837
# [2000]	train's l1: 13.6595	train's mae: 13.6595	test's l1: 14.472	test's mae: 14.472
# [2200]	train's l1: 13.58	train's mae: 13.58	test's l1: 14.4601	test's mae: 14.4601
# [2400]	train's l1: 13.5066	train's mae: 13.5066	test's l1: 14.4523	test's mae: 14.4523
# [2600]	train's l1: 13.4316	train's mae: 13.4316	test's l1: 14.4472	test's mae: 14.4472
# [2800]	train's l1: 13.3625	train's mae: 13.3625	test's l1: 14.4402	test's mae: 14.4402
# [3000]	train's l1: 13.294	train's mae: 13.294	test's l1: 14.4364	test's mae: 14.4364
# [3200]	train's l1: 13.227	train's mae: 13.227	test's l1: 14.4322	test's mae: 14.4322
# [3400]	train's l1: 13.1593	train's mae: 13.1593	test's l1: 14.4262	test's mae: 14.4262
# [3600]	train's l1: 13.0948	train's mae: 13.0948	test's l1: 14.4257	test's mae: 14.4257
# Early stopping, best iteration is:
# [3546]	train's l1: 13.1114	train's mae: 13.1114	test's l1: 14.4247	test's mae: 14.4247
#
# ================================================== Fold 6 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6921	train's mae: 15.6921	test's l1: 16.0222	test's mae: 16.0222
# [400]	train's l1: 14.6595	train's mae: 14.6595	test's l1: 15.125	test's mae: 15.125
# [600]	train's l1: 14.3794	train's mae: 14.3794	test's l1: 14.9533	test's mae: 14.9533
# [800]	train's l1: 14.2178	train's mae: 14.2178	test's l1: 14.8732	test's mae: 14.8732
# [1000]	train's l1: 14.0989	train's mae: 14.0989	test's l1: 14.8217	test's mae: 14.8217
# [1200]	train's l1: 13.9907	train's mae: 13.9907	test's l1: 14.784	test's mae: 14.784
# [1400]	train's l1: 13.8951	train's mae: 13.8951	test's l1: 14.7591	test's mae: 14.7591
# [1600]	train's l1: 13.8044	train's mae: 13.8044	test's l1: 14.7412	test's mae: 14.7412
# [1800]	train's l1: 13.7178	train's mae: 13.7178	test's l1: 14.7296	test's mae: 14.7296
# [2000]	train's l1: 13.6345	train's mae: 13.6345	test's l1: 14.7175	test's mae: 14.7175
# [2200]	train's l1: 13.5541	train's mae: 13.5541	test's l1: 14.7128	test's mae: 14.7128
# [2400]	train's l1: 13.4779	train's mae: 13.4779	test's l1: 14.7099	test's mae: 14.7099
# [2600]	train's l1: 13.406	train's mae: 13.406	test's l1: 14.7026	test's mae: 14.7026
# [2800]	train's l1: 13.3356	train's mae: 13.3356	test's l1: 14.6994	test's mae: 14.6994
# [3000]	train's l1: 13.2655	train's mae: 13.2655	test's l1: 14.6962	test's mae: 14.6962
# Early stopping, best iteration is:
# [2965]	train's l1: 13.2768	train's mae: 13.2768	test's l1: 14.6955	test's mae: 14.6955
#
# ================================================== Fold 7 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.676	train's mae: 15.676	test's l1: 16.1167	test's mae: 16.1167
# [400]	train's l1: 14.645	train's mae: 14.645	test's l1: 15.184	test's mae: 15.184
# [600]	train's l1: 14.3636	train's mae: 14.3636	test's l1: 15.0026	test's mae: 15.0026
# [800]	train's l1: 14.2032	train's mae: 14.2032	test's l1: 14.9374	test's mae: 14.9374
# [1000]	train's l1: 14.0832	train's mae: 14.0832	test's l1: 14.9038	test's mae: 14.9038
# [1200]	train's l1: 13.9758	train's mae: 13.9758	test's l1: 14.8816	test's mae: 14.8816
# [1400]	train's l1: 13.8794	train's mae: 13.8794	test's l1: 14.8667	test's mae: 14.8667
# [1600]	train's l1: 13.7901	train's mae: 13.7901	test's l1: 14.8535	test's mae: 14.8535
# [1800]	train's l1: 13.7039	train's mae: 13.7039	test's l1: 14.8421	test's mae: 14.8421
# [2000]	train's l1: 13.6196	train's mae: 13.6196	test's l1: 14.8352	test's mae: 14.8352
# [2200]	train's l1: 13.5401	train's mae: 13.5401	test's l1: 14.8302	test's mae: 14.8302
# [2400]	train's l1: 13.4671	train's mae: 13.4671	test's l1: 14.824	test's mae: 14.824
# [2600]	train's l1: 13.3929	train's mae: 13.3929	test's l1: 14.8212	test's mae: 14.8212
# Early stopping, best iteration is:
# [2711]	train's l1: 13.3543	train's mae: 13.3543	test's l1: 14.8168	test's mae: 14.8168
#
# ================================================== Fold 8 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7048	train's mae: 15.7048	test's l1: 15.7638	test's mae: 15.7638
# [400]	train's l1: 14.6722	train's mae: 14.6722	test's l1: 14.9059	test's mae: 14.9059
# [600]	train's l1: 14.3923	train's mae: 14.3923	test's l1: 14.7306	test's mae: 14.7306
# [800]	train's l1: 14.2308	train's mae: 14.2308	test's l1: 14.6678	test's mae: 14.6678
# [1000]	train's l1: 14.1093	train's mae: 14.1093	test's l1: 14.6286	test's mae: 14.6286
# [1200]	train's l1: 14.0019	train's mae: 14.0019	test's l1: 14.6022	test's mae: 14.6022
# [1400]	train's l1: 13.9078	train's mae: 13.9078	test's l1: 14.5863	test's mae: 14.5863
# [1600]	train's l1: 13.8177	train's mae: 13.8177	test's l1: 14.5723	test's mae: 14.5723
# [1800]	train's l1: 13.7331	train's mae: 13.7331	test's l1: 14.5613	test's mae: 14.5613
# [2000]	train's l1: 13.6487	train's mae: 13.6487	test's l1: 14.5478	test's mae: 14.5478
# [2200]	train's l1: 13.5683	train's mae: 13.5683	test's l1: 14.5449	test's mae: 14.5449
# [2400]	train's l1: 13.4926	train's mae: 13.4926	test's l1: 14.5379	test's mae: 14.5379
# [2600]	train's l1: 13.4186	train's mae: 13.4186	test's l1: 14.5334	test's mae: 14.5334
# [2800]	train's l1: 13.3496	train's mae: 13.3496	test's l1: 14.5298	test's mae: 14.5298
# Early stopping, best iteration is:
# [2740]	train's l1: 13.3694	train's mae: 13.3694	test's l1: 14.5287	test's mae: 14.5287
#
# ================================================== Fold 9 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6827	train's mae: 15.6827	test's l1: 16.0192	test's mae: 16.0192
# [400]	train's l1: 14.6523	train's mae: 14.6523	test's l1: 15.0696	test's mae: 15.0696
# [600]	train's l1: 14.3786	train's mae: 14.3786	test's l1: 14.8773	test's mae: 14.8773
# [800]	train's l1: 14.2218	train's mae: 14.2218	test's l1: 14.8069	test's mae: 14.8069
# [1000]	train's l1: 14.1066	train's mae: 14.1066	test's l1: 14.7674	test's mae: 14.7674
# [1200]	train's l1: 13.9984	train's mae: 13.9984	test's l1: 14.7334	test's mae: 14.7334
# [1400]	train's l1: 13.9039	train's mae: 13.9039	test's l1: 14.7068	test's mae: 14.7068
# [1600]	train's l1: 13.8171	train's mae: 13.8171	test's l1: 14.6882	test's mae: 14.6882
# [1800]	train's l1: 13.7296	train's mae: 13.7296	test's l1: 14.6682	test's mae: 14.6682
# [2000]	train's l1: 13.648	train's mae: 13.648	test's l1: 14.6543	test's mae: 14.6543
# [2200]	train's l1: 13.5688	train's mae: 13.5688	test's l1: 14.6419	test's mae: 14.6419
# [2400]	train's l1: 13.4967	train's mae: 13.4967	test's l1: 14.6356	test's mae: 14.6356
# [2600]	train's l1: 13.426	train's mae: 13.426	test's l1: 14.6295	test's mae: 14.6295
# [2800]	train's l1: 13.354	train's mae: 13.354	test's l1: 14.6207	test's mae: 14.6207
# [3000]	train's l1: 13.2859	train's mae: 13.2859	test's l1: 14.6147	test's mae: 14.6147
# [3200]	train's l1: 13.2182	train's mae: 13.2182	test's l1: 14.6049	test's mae: 14.6049
# [3400]	train's l1: 13.1534	train's mae: 13.1534	test's l1: 14.6019	test's mae: 14.6019
# [3600]	train's l1: 13.0884	train's mae: 13.0884	test's l1: 14.6	test's mae: 14.6
# Early stopping, best iteration is:
# [3542]	train's l1: 13.1058	train's mae: 13.1058	test's l1: 14.599	test's mae: 14.599
#
# ================================================== Fold 10 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7131	train's mae: 15.7131	test's l1: 15.7905	test's mae: 15.7905
# [400]	train's l1: 14.6863	train's mae: 14.6863	test's l1: 14.8514	test's mae: 14.8514
# [600]	train's l1: 14.408	train's mae: 14.408	test's l1: 14.6339	test's mae: 14.6339
# [800]	train's l1: 14.2504	train's mae: 14.2504	test's l1: 14.5344	test's mae: 14.5344
# [1000]	train's l1: 14.1255	train's mae: 14.1255	test's l1: 14.4788	test's mae: 14.4788
# [1200]	train's l1: 14.0214	train's mae: 14.0214	test's l1: 14.4394	test's mae: 14.4394
# [1400]	train's l1: 13.9272	train's mae: 13.9272	test's l1: 14.416	test's mae: 14.416
# [1600]	train's l1: 13.8406	train's mae: 13.8406	test's l1: 14.3978	test's mae: 14.3978
# [1800]	train's l1: 13.7568	train's mae: 13.7568	test's l1: 14.3866	test's mae: 14.3866
# [2000]	train's l1: 13.6795	train's mae: 13.6795	test's l1: 14.3783	test's mae: 14.3783
# [2200]	train's l1: 13.602	train's mae: 13.602	test's l1: 14.3707	test's mae: 14.3707
# Early stopping, best iteration is:
# [2265]	train's l1: 13.577	train's mae: 13.577	test's l1: 14.3655	test's mae: 14.3655
# ====================================================================================================
# 0.06406284143579073	0.06464308897950909	0.06461268850377501	0.06340511233010519	0.06483091823741055	0.0637125445969977	0.06322408649168675	0.06439696287137099	0.06410658335599471	0.06508099753222053
# min score: 0.063224
# max score: 0.065081
# median score: 0.064252
# mean score: 0.064208
# [601.75925751 523.58231039 670.44861233 675.56708782 657.43124736
#  613.94712394 640.69436939 569.2464948  674.36730938 590.12698276]

# %%
x, y = train_df[feature_name3], train_df['信用分'].values
x_test = test_df[feature_name3]

model = kf_lgbm(x=x,y=y,x_test=x_test,learning_rate=0.01, 
                stratify=True, 
                min_split_gain=1,
                categorical_feature=['用户话费敏感度'],
                boosting_type='gbdt',
                early_stopping_rounds=80,
                fair_c=25, 
                huber_delta=2,
                max_cat_to_onehot=4,
                objective="mae_fair",
                eval_metric="mae",
                subsample_freq=2,
                min_child_samples=20,
                num_leaves=31,
                bagging_fraction=0.8,
                feature_fraction=0.5,
                max_depth=5,
                output_dir=output_dir,
                name='gotcha_lgb3',
                n_estimators=8000)
# Out:
# ================================================== Fold 1 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6113	train's mae: 15.6113	test's l1: 15.8654	test's mae: 15.8654
# [400]	train's l1: 14.6492	train's mae: 14.6492	test's l1: 15.0782	test's mae: 15.0782
# [600]	train's l1: 14.3951	train's mae: 14.3951	test's l1: 14.9205	test's mae: 14.9205
# [800]	train's l1: 14.2447	train's mae: 14.2447	test's l1: 14.849	test's mae: 14.849
# [1000]	train's l1: 14.1242	train's mae: 14.1242	test's l1: 14.798	test's mae: 14.798
# [1200]	train's l1: 14.0181	train's mae: 14.0181	test's l1: 14.7622	test's mae: 14.7622
# [1400]	train's l1: 13.9196	train's mae: 13.9196	test's l1: 14.7293	test's mae: 14.7293
# [1600]	train's l1: 13.8311	train's mae: 13.8311	test's l1: 14.7093	test's mae: 14.7093
# [1800]	train's l1: 13.7485	train's mae: 13.7485	test's l1: 14.6958	test's mae: 14.6958
# [2000]	train's l1: 13.6685	train's mae: 13.6685	test's l1: 14.6816	test's mae: 14.6816
# [2200]	train's l1: 13.5911	train's mae: 13.5911	test's l1: 14.6701	test's mae: 14.6701
# [2400]	train's l1: 13.518	train's mae: 13.518	test's l1: 14.6608	test's mae: 14.6608
# [2600]	train's l1: 13.4486	train's mae: 13.4486	test's l1: 14.6491	test's mae: 14.6491
# [2800]	train's l1: 13.383	train's mae: 13.383	test's l1: 14.6392	test's mae: 14.6392
# [3000]	train's l1: 13.3125	train's mae: 13.3125	test's l1: 14.6312	test's mae: 14.6312
# [3200]	train's l1: 13.2485	train's mae: 13.2485	test's l1: 14.6254	test's mae: 14.6254
# [3400]	train's l1: 13.1839	train's mae: 13.1839	test's l1: 14.6198	test's mae: 14.6198
# [3600]	train's l1: 13.1189	train's mae: 13.1189	test's l1: 14.6151	test's mae: 14.6151
# Early stopping, best iteration is:
# [3666]	train's l1: 13.1001	train's mae: 13.1001	test's l1: 14.6143	test's mae: 14.6143
#
# ================================================== Fold 2 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6227	train's mae: 15.6227	test's l1: 15.8126	test's mae: 15.8126
# [400]	train's l1: 14.6703	train's mae: 14.6703	test's l1: 14.9032	test's mae: 14.9032
# [600]	train's l1: 14.4134	train's mae: 14.4134	test's l1: 14.715	test's mae: 14.715
# [800]	train's l1: 14.2677	train's mae: 14.2677	test's l1: 14.6347	test's mae: 14.6347
# [1000]	train's l1: 14.1484	train's mae: 14.1484	test's l1: 14.5904	test's mae: 14.5904
# [1200]	train's l1: 14.0478	train's mae: 14.0478	test's l1: 14.56	test's mae: 14.56
# [1400]	train's l1: 13.952	train's mae: 13.952	test's l1: 14.5432	test's mae: 14.5432
# [1600]	train's l1: 13.8629	train's mae: 13.8629	test's l1: 14.5266	test's mae: 14.5266
# [1800]	train's l1: 13.7812	train's mae: 13.7812	test's l1: 14.5098	test's mae: 14.5098
# [2000]	train's l1: 13.6988	train's mae: 13.6988	test's l1: 14.4988	test's mae: 14.4988
# [2200]	train's l1: 13.6173	train's mae: 13.6173	test's l1: 14.4894	test's mae: 14.4894
# Early stopping, best iteration is:
# [2265]	train's l1: 13.5943	train's mae: 13.5943	test's l1: 14.4862	test's mae: 14.4862
#
# ================================================== Fold 3 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6291	train's mae: 15.6291	test's l1: 15.6516	test's mae: 15.6516
# [400]	train's l1: 14.6672	train's mae: 14.6672	test's l1: 14.8233	test's mae: 14.8233
# [600]	train's l1: 14.4193	train's mae: 14.4193	test's l1: 14.6803	test's mae: 14.6803
# [800]	train's l1: 14.2639	train's mae: 14.2639	test's l1: 14.6165	test's mae: 14.6165
# [1000]	train's l1: 14.1411	train's mae: 14.1411	test's l1: 14.5795	test's mae: 14.5795
# [1200]	train's l1: 14.0359	train's mae: 14.0359	test's l1: 14.5496	test's mae: 14.5496
# [1400]	train's l1: 13.9406	train's mae: 13.9406	test's l1: 14.5274	test's mae: 14.5274
# [1600]	train's l1: 13.8489	train's mae: 13.8489	test's l1: 14.5128	test's mae: 14.5128
# [1800]	train's l1: 13.7638	train's mae: 13.7638	test's l1: 14.5031	test's mae: 14.5031
# [2000]	train's l1: 13.6832	train's mae: 13.6832	test's l1: 14.4922	test's mae: 14.4922
# [2200]	train's l1: 13.6082	train's mae: 13.6082	test's l1: 14.4847	test's mae: 14.4847
# [2400]	train's l1: 13.5323	train's mae: 13.5323	test's l1: 14.4792	test's mae: 14.4792
# [2600]	train's l1: 13.4578	train's mae: 13.4578	test's l1: 14.4771	test's mae: 14.4771
# Early stopping, best iteration is:
# [2672]	train's l1: 13.4329	train's mae: 13.4329	test's l1: 14.4757	test's mae: 14.4757
#
# ================================================== Fold 4 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.5966	train's mae: 15.5966	test's l1: 16.0033	test's mae: 16.0033
# [400]	train's l1: 14.6428	train's mae: 14.6428	test's l1: 15.1559	test's mae: 15.1559
# [600]	train's l1: 14.383	train's mae: 14.383	test's l1: 14.9911	test's mae: 14.9911
# [800]	train's l1: 14.2385	train's mae: 14.2385	test's l1: 14.9415	test's mae: 14.9415
# [1000]	train's l1: 14.1182	train's mae: 14.1182	test's l1: 14.9099	test's mae: 14.9099
# [1200]	train's l1: 14.0139	train's mae: 14.0139	test's l1: 14.8812	test's mae: 14.8812
# [1400]	train's l1: 13.9177	train's mae: 13.9177	test's l1: 14.8613	test's mae: 14.8613
# [1600]	train's l1: 13.828	train's mae: 13.828	test's l1: 14.8388	test's mae: 14.8388
# [1800]	train's l1: 13.741	train's mae: 13.741	test's l1: 14.8206	test's mae: 14.8206
# [2000]	train's l1: 13.6625	train's mae: 13.6625	test's l1: 14.8022	test's mae: 14.8022
# [2200]	train's l1: 13.5851	train's mae: 13.5851	test's l1: 14.7936	test's mae: 14.7936
# [2400]	train's l1: 13.5102	train's mae: 13.5102	test's l1: 14.7842	test's mae: 14.7842
# [2600]	train's l1: 13.4388	train's mae: 13.4388	test's l1: 14.7794	test's mae: 14.7794
# [2800]	train's l1: 13.3705	train's mae: 13.3705	test's l1: 14.7729	test's mae: 14.7729
# [3000]	train's l1: 13.3015	train's mae: 13.3015	test's l1: 14.7687	test's mae: 14.7687
# Early stopping, best iteration is:
# [3072]	train's l1: 13.2767	train's mae: 13.2767	test's l1: 14.7662	test's mae: 14.7662
#
# ================================================== Fold 5 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6229	train's mae: 15.6229	test's l1: 15.7452	test's mae: 15.7452
# [400]	train's l1: 14.6632	train's mae: 14.6632	test's l1: 14.8849	test's mae: 14.8849
# [600]	train's l1: 14.407	train's mae: 14.407	test's l1: 14.7018	test's mae: 14.7018
# [800]	train's l1: 14.2629	train's mae: 14.2629	test's l1: 14.6196	test's mae: 14.6196
# [1000]	train's l1: 14.1459	train's mae: 14.1459	test's l1: 14.5716	test's mae: 14.5716
# [1200]	train's l1: 14.04	train's mae: 14.04	test's l1: 14.5391	test's mae: 14.5391
# [1400]	train's l1: 13.941	train's mae: 13.941	test's l1: 14.5161	test's mae: 14.5161
# [1600]	train's l1: 13.852	train's mae: 13.852	test's l1: 14.4993	test's mae: 14.4993
# [1800]	train's l1: 13.763	train's mae: 13.763	test's l1: 14.4809	test's mae: 14.4809
# [2000]	train's l1: 13.6847	train's mae: 13.6847	test's l1: 14.4706	test's mae: 14.4706
# [2200]	train's l1: 13.6059	train's mae: 13.6059	test's l1: 14.4615	test's mae: 14.4615
# [2400]	train's l1: 13.5317	train's mae: 13.5317	test's l1: 14.4541	test's mae: 14.4541
# [2600]	train's l1: 13.4584	train's mae: 13.4584	test's l1: 14.4481	test's mae: 14.4481
# [2800]	train's l1: 13.389	train's mae: 13.389	test's l1: 14.443	test's mae: 14.443
# [3000]	train's l1: 13.3203	train's mae: 13.3203	test's l1: 14.4354	test's mae: 14.4354
# Early stopping, best iteration is:
# [3103]	train's l1: 13.2858	train's mae: 13.2858	test's l1: 14.4326	test's mae: 14.4326
#
# ================================================== Fold 6 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6072	train's mae: 15.6072	test's l1: 15.9268	test's mae: 15.9268
# [400]	train's l1: 14.649	train's mae: 14.649	test's l1: 15.0993	test's mae: 15.0993
# [600]	train's l1: 14.3936	train's mae: 14.3936	test's l1: 14.948	test's mae: 14.948
# [800]	train's l1: 14.2459	train's mae: 14.2459	test's l1: 14.8724	test's mae: 14.8724
# [1000]	train's l1: 14.1317	train's mae: 14.1317	test's l1: 14.8227	test's mae: 14.8227
# [1200]	train's l1: 14.0259	train's mae: 14.0259	test's l1: 14.7847	test's mae: 14.7847
# [1400]	train's l1: 13.9296	train's mae: 13.9296	test's l1: 14.7598	test's mae: 14.7598
# [1600]	train's l1: 13.8426	train's mae: 13.8426	test's l1: 14.7382	test's mae: 14.7382
# [1800]	train's l1: 13.7557	train's mae: 13.7557	test's l1: 14.7299	test's mae: 14.7299
# [2000]	train's l1: 13.6754	train's mae: 13.6754	test's l1: 14.7178	test's mae: 14.7178
# [2200]	train's l1: 13.5967	train's mae: 13.5967	test's l1: 14.7095	test's mae: 14.7095
# [2400]	train's l1: 13.5218	train's mae: 13.5218	test's l1: 14.7044	test's mae: 14.7044
# [2600]	train's l1: 13.4505	train's mae: 13.4505	test's l1: 14.6973	test's mae: 14.6973
# [2800]	train's l1: 13.381	train's mae: 13.381	test's l1: 14.6902	test's mae: 14.6902
# Early stopping, best iteration is:
# [2865]	train's l1: 13.3578	train's mae: 13.3578	test's l1: 14.6877	test's mae: 14.6877
#
# ================================================== Fold 7 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.5946	train's mae: 15.5946	test's l1: 16.0032	test's mae: 16.0032
# [400]	train's l1: 14.64	train's mae: 14.64	test's l1: 15.1432	test's mae: 15.1432
# [600]	train's l1: 14.3854	train's mae: 14.3854	test's l1: 14.9812	test's mae: 14.9812
# [800]	train's l1: 14.2355	train's mae: 14.2355	test's l1: 14.9263	test's mae: 14.9263
# [1000]	train's l1: 14.116	train's mae: 14.116	test's l1: 14.8964	test's mae: 14.8964
# [1200]	train's l1: 14.0076	train's mae: 14.0076	test's l1: 14.8691	test's mae: 14.8691
# [1400]	train's l1: 13.9088	train's mae: 13.9088	test's l1: 14.8574	test's mae: 14.8574
# [1600]	train's l1: 13.8197	train's mae: 13.8197	test's l1: 14.8469	test's mae: 14.8469
# [1800]	train's l1: 13.7337	train's mae: 13.7337	test's l1: 14.8329	test's mae: 14.8329
# [2000]	train's l1: 13.6505	train's mae: 13.6505	test's l1: 14.8244	test's mae: 14.8244
# [2200]	train's l1: 13.5711	train's mae: 13.5711	test's l1: 14.8169	test's mae: 14.8169
# [2400]	train's l1: 13.497	train's mae: 13.497	test's l1: 14.8113	test's mae: 14.8113
# Early stopping, best iteration is:
# [2388]	train's l1: 13.5015	train's mae: 13.5015	test's l1: 14.8112	test's mae: 14.8112
#
# ================================================== Fold 8 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.621	train's mae: 15.621	test's l1: 15.696	test's mae: 15.696
# [400]	train's l1: 14.67	train's mae: 14.67	test's l1: 14.9009	test's mae: 14.9009
# [600]	train's l1: 14.4138	train's mae: 14.4138	test's l1: 14.7346	test's mae: 14.7346
# [800]	train's l1: 14.2635	train's mae: 14.2635	test's l1: 14.6696	test's mae: 14.6696
# [1000]	train's l1: 14.145	train's mae: 14.145	test's l1: 14.6256	test's mae: 14.6256
# [1200]	train's l1: 14.0394	train's mae: 14.0394	test's l1: 14.591	test's mae: 14.591
# [1400]	train's l1: 13.9468	train's mae: 13.9468	test's l1: 14.5716	test's mae: 14.5716
# [1600]	train's l1: 13.8573	train's mae: 13.8573	test's l1: 14.5572	test's mae: 14.5572
# [1800]	train's l1: 13.7726	train's mae: 13.7726	test's l1: 14.5447	test's mae: 14.5447
# [2000]	train's l1: 13.6913	train's mae: 13.6913	test's l1: 14.5294	test's mae: 14.5294
# [2200]	train's l1: 13.6126	train's mae: 13.6126	test's l1: 14.5247	test's mae: 14.5247
# [2400]	train's l1: 13.5384	train's mae: 13.5384	test's l1: 14.5165	test's mae: 14.5165
# [2600]	train's l1: 13.4633	train's mae: 13.4633	test's l1: 14.5137	test's mae: 14.5137
# [2800]	train's l1: 13.3952	train's mae: 13.3952	test's l1: 14.5085	test's mae: 14.5085
# [3000]	train's l1: 13.3289	train's mae: 13.3289	test's l1: 14.5071	test's mae: 14.5071
# Early stopping, best iteration is:
# [2954]	train's l1: 13.3428	train's mae: 13.3428	test's l1: 14.5059	test's mae: 14.5059
#
# ================================================== Fold 9 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6055	train's mae: 15.6055	test's l1: 15.9358	test's mae: 15.9358
# [400]	train's l1: 14.6484	train's mae: 14.6484	test's l1: 15.0573	test's mae: 15.0573
# [600]	train's l1: 14.399	train's mae: 14.399	test's l1: 14.8872	test's mae: 14.8872
# [800]	train's l1: 14.2491	train's mae: 14.2491	test's l1: 14.8202	test's mae: 14.8202
# [1000]	train's l1: 14.1369	train's mae: 14.1369	test's l1: 14.7822	test's mae: 14.7822
# [1200]	train's l1: 14.0326	train's mae: 14.0326	test's l1: 14.7464	test's mae: 14.7464
# [1400]	train's l1: 13.9402	train's mae: 13.9402	test's l1: 14.7214	test's mae: 14.7214
# [1600]	train's l1: 13.8522	train's mae: 13.8522	test's l1: 14.7054	test's mae: 14.7054
# [1800]	train's l1: 13.7632	train's mae: 13.7632	test's l1: 14.6846	test's mae: 14.6846
# [2000]	train's l1: 13.6812	train's mae: 13.6812	test's l1: 14.6701	test's mae: 14.6701
# [2200]	train's l1: 13.6048	train's mae: 13.6048	test's l1: 14.6607	test's mae: 14.6607
# [2400]	train's l1: 13.5315	train's mae: 13.5315	test's l1: 14.6541	test's mae: 14.6541
# [2600]	train's l1: 13.4589	train's mae: 13.4589	test's l1: 14.6501	test's mae: 14.6501
# [2800]	train's l1: 13.3888	train's mae: 13.3888	test's l1: 14.6427	test's mae: 14.6427
# [3000]	train's l1: 13.3214	train's mae: 13.3214	test's l1: 14.6351	test's mae: 14.6351
# [3200]	train's l1: 13.255	train's mae: 13.255	test's l1: 14.6291	test's mae: 14.6291
# [3400]	train's l1: 13.1889	train's mae: 13.1889	test's l1: 14.6264	test's mae: 14.6264
# Early stopping, best iteration is:
# [3442]	train's l1: 13.1753	train's mae: 13.1753	test's l1: 14.6249	test's mae: 14.6249
#
# ================================================== Fold 10 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6278	train's mae: 15.6278	test's l1: 15.6746	test's mae: 15.6746
# [400]	train's l1: 14.6804	train's mae: 14.6804	test's l1: 14.8063	test's mae: 14.8063
# [600]	train's l1: 14.4302	train's mae: 14.4302	test's l1: 14.6133	test's mae: 14.6133
# [800]	train's l1: 14.2811	train's mae: 14.2811	test's l1: 14.5225	test's mae: 14.5225
# [1000]	train's l1: 14.161	train's mae: 14.161	test's l1: 14.4657	test's mae: 14.4657
# [1200]	train's l1: 14.0585	train's mae: 14.0585	test's l1: 14.4267	test's mae: 14.4267
# [1400]	train's l1: 13.9637	train's mae: 13.9637	test's l1: 14.4017	test's mae: 14.4017
# [1600]	train's l1: 13.8736	train's mae: 13.8736	test's l1: 14.3791	test's mae: 14.3791
# [1800]	train's l1: 13.7899	train's mae: 13.7899	test's l1: 14.3653	test's mae: 14.3653
# [2000]	train's l1: 13.7125	train's mae: 13.7125	test's l1: 14.3589	test's mae: 14.3589
# [2200]	train's l1: 13.6334	train's mae: 13.6334	test's l1: 14.3482	test's mae: 14.3482
# Early stopping, best iteration is:
# [2284]	train's l1: 13.6008	train's mae: 13.6008	test's l1: 14.3443	test's mae: 14.3443
# ====================================================================================================
# 0.0640437441271368	0.06457360320104055	0.06461743294789277	0.06342692537568796	0.06479804615100941	0.06374435478019916	0.06324649496746182	0.06449154611155238	0.06400057968815352	0.06517098976148367
# min score: 0.063246
# max score: 0.065171
# median score: 0.064268
# mean score: 0.064211
# [601.47670827 523.05220271 669.99712863 676.02947299 657.80214777
#  614.0796084  640.22980233 569.79640309 674.6928045  589.3802724 ]

# %%
x, y = train_df[feature_name4], train_df['信用分'].values
x_test = test_df[feature_name4]

model = kf_lgbm(x=x,y=y,x_test=x_test,learning_rate=0.01, 
                stratify=True,
                min_split_gain=1,
                categorical_feature=['用户话费敏感度'],
                boosting_type='gbdt',
                early_stopping_rounds=80,
                fair_c=23, 
                huber_delta=2,
                max_cat_to_onehot=4,
                objective="fair_huber",
                eval_metric="mae",
                subsample_freq=2,
                min_child_samples=20,
                num_leaves=31,
                bagging_fraction=0.8,
                feature_fraction=0.5,
                max_depth=5,
                output_dir=output_dir,
                name='gotcha_lgb4',
                n_estimators=8000)
# Out:
# ================================================== Fold 1 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7028	train's mae: 15.7028	test's l1: 15.9519	test's mae: 15.9519
# [400]	train's l1: 14.6729	train's mae: 14.6729	test's l1: 15.0955	test's mae: 15.0955
# [600]	train's l1: 14.3987	train's mae: 14.3987	test's l1: 14.9265	test's mae: 14.9265
# [800]	train's l1: 14.2423	train's mae: 14.2423	test's l1: 14.8486	test's mae: 14.8486
# [1000]	train's l1: 14.1208	train's mae: 14.1208	test's l1: 14.7959	test's mae: 14.7959
# [1200]	train's l1: 14.0167	train's mae: 14.0167	test's l1: 14.7588	test's mae: 14.7588
# [1400]	train's l1: 13.9235	train's mae: 13.9235	test's l1: 14.7299	test's mae: 14.7299
# [1600]	train's l1: 13.836	train's mae: 13.836	test's l1: 14.7125	test's mae: 14.7125
# [1800]	train's l1: 13.7545	train's mae: 13.7545	test's l1: 14.6952	test's mae: 14.6952
# [2000]	train's l1: 13.6773	train's mae: 13.6773	test's l1: 14.6835	test's mae: 14.6835
# [2200]	train's l1: 13.603	train's mae: 13.603	test's l1: 14.6721	test's mae: 14.6721
# [2400]	train's l1: 13.5327	train's mae: 13.5327	test's l1: 14.6627	test's mae: 14.6627
# [2600]	train's l1: 13.4664	train's mae: 13.4664	test's l1: 14.6501	test's mae: 14.6501
# [2800]	train's l1: 13.4029	train's mae: 13.4029	test's l1: 14.6397	test's mae: 14.6397
# [3000]	train's l1: 13.3371	train's mae: 13.3371	test's l1: 14.6341	test's mae: 14.6341
# [3200]	train's l1: 13.2759	train's mae: 13.2759	test's l1: 14.6288	test's mae: 14.6288
# [3400]	train's l1: 13.2161	train's mae: 13.2161	test's l1: 14.6259	test's mae: 14.6259
# [3600]	train's l1: 13.1546	train's mae: 13.1546	test's l1: 14.6236	test's mae: 14.6236
# Early stopping, best iteration is:
# [3569]	train's l1: 13.1648	train's mae: 13.1648	test's l1: 14.622	test's mae: 14.622
#
# ================================================== Fold 2 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7088	train's mae: 15.7088	test's l1: 15.9331	test's mae: 15.9331
# [400]	train's l1: 14.693	train's mae: 14.693	test's l1: 14.9541	test's mae: 14.9541
# [600]	train's l1: 14.4148	train's mae: 14.4148	test's l1: 14.7464	test's mae: 14.7464
# [800]	train's l1: 14.2624	train's mae: 14.2624	test's l1: 14.6588	test's mae: 14.6588
# [1000]	train's l1: 14.1443	train's mae: 14.1443	test's l1: 14.6076	test's mae: 14.6076
# [1200]	train's l1: 14.0437	train's mae: 14.0437	test's l1: 14.5761	test's mae: 14.5761
# [1400]	train's l1: 13.952	train's mae: 13.952	test's l1: 14.5576	test's mae: 14.5576
# [1600]	train's l1: 13.8675	train's mae: 13.8675	test's l1: 14.5379	test's mae: 14.5379
# [1800]	train's l1: 13.7872	train's mae: 13.7872	test's l1: 14.5229	test's mae: 14.5229
# [2000]	train's l1: 13.7074	train's mae: 13.7074	test's l1: 14.5141	test's mae: 14.5141
# [2200]	train's l1: 13.6296	train's mae: 13.6296	test's l1: 14.5052	test's mae: 14.5052
# [2400]	train's l1: 13.5612	train's mae: 13.5612	test's l1: 14.4992	test's mae: 14.4992
# [2600]	train's l1: 13.4911	train's mae: 13.4911	test's l1: 14.4935	test's mae: 14.4935
# Early stopping, best iteration is:
# [2618]	train's l1: 13.4851	train's mae: 13.4851	test's l1: 14.4931	test's mae: 14.4931
#
# ================================================== Fold 3 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7249	train's mae: 15.7249	test's l1: 15.7374	test's mae: 15.7374
# [400]	train's l1: 14.6977	train's mae: 14.6977	test's l1: 14.8607	test's mae: 14.8607
# [600]	train's l1: 14.4277	train's mae: 14.4277	test's l1: 14.7104	test's mae: 14.7104
# [800]	train's l1: 14.2704	train's mae: 14.2704	test's l1: 14.6432	test's mae: 14.6432
# [1000]	train's l1: 14.1505	train's mae: 14.1505	test's l1: 14.6032	test's mae: 14.6032
# [1200]	train's l1: 14.0483	train's mae: 14.0483	test's l1: 14.5744	test's mae: 14.5744
# [1400]	train's l1: 13.9565	train's mae: 13.9565	test's l1: 14.5545	test's mae: 14.5545
# [1600]	train's l1: 13.866	train's mae: 13.866	test's l1: 14.5385	test's mae: 14.5385
# [1800]	train's l1: 13.783	train's mae: 13.783	test's l1: 14.5279	test's mae: 14.5279
# [2000]	train's l1: 13.7083	train's mae: 13.7083	test's l1: 14.5194	test's mae: 14.5194
# [2200]	train's l1: 13.6357	train's mae: 13.6357	test's l1: 14.511	test's mae: 14.511
# [2400]	train's l1: 13.5614	train's mae: 13.5614	test's l1: 14.5025	test's mae: 14.5025
# Early stopping, best iteration is:
# [2452]	train's l1: 13.5431	train's mae: 13.5431	test's l1: 14.5004	test's mae: 14.5004
#
# ================================================== Fold 4 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6842	train's mae: 15.6842	test's l1: 16.1052	test's mae: 16.1052
# [400]	train's l1: 14.6627	train's mae: 14.6627	test's l1: 15.1859	test's mae: 15.1859
# [600]	train's l1: 14.3855	train's mae: 14.3855	test's l1: 15.0138	test's mae: 15.0138
# [800]	train's l1: 14.2366	train's mae: 14.2366	test's l1: 14.961	test's mae: 14.961
# [1000]	train's l1: 14.1183	train's mae: 14.1183	test's l1: 14.9299	test's mae: 14.9299
# [1200]	train's l1: 14.0143	train's mae: 14.0143	test's l1: 14.9004	test's mae: 14.9004
# [1400]	train's l1: 13.9221	train's mae: 13.9221	test's l1: 14.8801	test's mae: 14.8801
# [1600]	train's l1: 13.8332	train's mae: 13.8332	test's l1: 14.8593	test's mae: 14.8593
# [1800]	train's l1: 13.7482	train's mae: 13.7482	test's l1: 14.8438	test's mae: 14.8438
# [2000]	train's l1: 13.6688	train's mae: 13.6688	test's l1: 14.8273	test's mae: 14.8273
# [2200]	train's l1: 13.5948	train's mae: 13.5948	test's l1: 14.8181	test's mae: 14.8181
# [2400]	train's l1: 13.5229	train's mae: 13.5229	test's l1: 14.8087	test's mae: 14.8087
# [2600]	train's l1: 13.4548	train's mae: 13.4548	test's l1: 14.8046	test's mae: 14.8046
# [2800]	train's l1: 13.3903	train's mae: 13.3903	test's l1: 14.8	test's mae: 14.8
# [3000]	train's l1: 13.3238	train's mae: 13.3238	test's l1: 14.7962	test's mae: 14.7962
# [3200]	train's l1: 13.2589	train's mae: 13.2589	test's l1: 14.795	test's mae: 14.795
# Early stopping, best iteration is:
# [3133]	train's l1: 13.2814	train's mae: 13.2814	test's l1: 14.7944	test's mae: 14.7944
#
# ================================================== Fold 5 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7117	train's mae: 15.7117	test's l1: 15.8478	test's mae: 15.8478
# [400]	train's l1: 14.6864	train's mae: 14.6864	test's l1: 14.9139	test's mae: 14.9139
# [600]	train's l1: 14.416	train's mae: 14.416	test's l1: 14.7234	test's mae: 14.7234
# [800]	train's l1: 14.2673	train's mae: 14.2673	test's l1: 14.6388	test's mae: 14.6388
# [1000]	train's l1: 14.1503	train's mae: 14.1503	test's l1: 14.5912	test's mae: 14.5912
# [1200]	train's l1: 14.0471	train's mae: 14.0471	test's l1: 14.5563	test's mae: 14.5563
# [1400]	train's l1: 13.9513	train's mae: 13.9513	test's l1: 14.5298	test's mae: 14.5298
# [1600]	train's l1: 13.8643	train's mae: 13.8643	test's l1: 14.5103	test's mae: 14.5103
# [1800]	train's l1: 13.7791	train's mae: 13.7791	test's l1: 14.4917	test's mae: 14.4917
# [2000]	train's l1: 13.7025	train's mae: 13.7025	test's l1: 14.4784	test's mae: 14.4784
# [2200]	train's l1: 13.6274	train's mae: 13.6274	test's l1: 14.4657	test's mae: 14.4657
# [2400]	train's l1: 13.5553	train's mae: 13.5553	test's l1: 14.4549	test's mae: 14.4549
# [2600]	train's l1: 13.4821	train's mae: 13.4821	test's l1: 14.4481	test's mae: 14.4481
# [2800]	train's l1: 13.4151	train's mae: 13.4151	test's l1: 14.4409	test's mae: 14.4409
# [3000]	train's l1: 13.3508	train's mae: 13.3508	test's l1: 14.4357	test's mae: 14.4357
# [3200]	train's l1: 13.287	train's mae: 13.287	test's l1: 14.4295	test's mae: 14.4295
# [3400]	train's l1: 13.2228	train's mae: 13.2228	test's l1: 14.4244	test's mae: 14.4244
# Early stopping, best iteration is:
# [3480]	train's l1: 13.1976	train's mae: 13.1976	test's l1: 14.421	test's mae: 14.421
#
# ================================================== Fold 6 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7018	train's mae: 15.7018	test's l1: 16.02	test's mae: 16.02
# [400]	train's l1: 14.6748	train's mae: 14.6748	test's l1: 15.1214	test's mae: 15.1214
# [600]	train's l1: 14.4011	train's mae: 14.4011	test's l1: 14.9517	test's mae: 14.9517
# [800]	train's l1: 14.2451	train's mae: 14.2451	test's l1: 14.8727	test's mae: 14.8727
# [1000]	train's l1: 14.1305	train's mae: 14.1305	test's l1: 14.8274	test's mae: 14.8274
# [1200]	train's l1: 14.0278	train's mae: 14.0278	test's l1: 14.7921	test's mae: 14.7921
# [1400]	train's l1: 13.9336	train's mae: 13.9336	test's l1: 14.7657	test's mae: 14.7657
# [1600]	train's l1: 13.8462	train's mae: 13.8462	test's l1: 14.747	test's mae: 14.747
# [1800]	train's l1: 13.7614	train's mae: 13.7614	test's l1: 14.7332	test's mae: 14.7332
# [2000]	train's l1: 13.6828	train's mae: 13.6828	test's l1: 14.7205	test's mae: 14.7205
# [2200]	train's l1: 13.6061	train's mae: 13.6061	test's l1: 14.7136	test's mae: 14.7136
# [2400]	train's l1: 13.5332	train's mae: 13.5332	test's l1: 14.7081	test's mae: 14.7081
# [2600]	train's l1: 13.4656	train's mae: 13.4656	test's l1: 14.7003	test's mae: 14.7003
# [2800]	train's l1: 13.4002	train's mae: 13.4002	test's l1: 14.6933	test's mae: 14.6933
# [3000]	train's l1: 13.3349	train's mae: 13.3349	test's l1: 14.6876	test's mae: 14.6876
# [3200]	train's l1: 13.2699	train's mae: 13.2699	test's l1: 14.6838	test's mae: 14.6838
# Early stopping, best iteration is:
# [3136]	train's l1: 13.2918	train's mae: 13.2918	test's l1: 14.6835	test's mae: 14.6835
#
# ================================================== Fold 7 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6833	train's mae: 15.6833	test's l1: 16.1002	test's mae: 16.1002
# [400]	train's l1: 14.6585	train's mae: 14.6585	test's l1: 15.173	test's mae: 15.173
# [600]	train's l1: 14.386	train's mae: 14.386	test's l1: 14.9971	test's mae: 14.9971
# [800]	train's l1: 14.2299	train's mae: 14.2299	test's l1: 14.9328	test's mae: 14.9328
# [1000]	train's l1: 14.1114	train's mae: 14.1114	test's l1: 14.9031	test's mae: 14.9031
# [1200]	train's l1: 14.0035	train's mae: 14.0035	test's l1: 14.8798	test's mae: 14.8798
# [1400]	train's l1: 13.9087	train's mae: 13.9087	test's l1: 14.8636	test's mae: 14.8636
# [1600]	train's l1: 13.8207	train's mae: 13.8207	test's l1: 14.8514	test's mae: 14.8514
# [1800]	train's l1: 13.7372	train's mae: 13.7372	test's l1: 14.8386	test's mae: 14.8386
# [2000]	train's l1: 13.6563	train's mae: 13.6563	test's l1: 14.8317	test's mae: 14.8317
# [2200]	train's l1: 13.5804	train's mae: 13.5804	test's l1: 14.827	test's mae: 14.827
# [2400]	train's l1: 13.51	train's mae: 13.51	test's l1: 14.8217	test's mae: 14.8217
# [2600]	train's l1: 13.4389	train's mae: 13.4389	test's l1: 14.819	test's mae: 14.819
# [2800]	train's l1: 13.3745	train's mae: 13.3745	test's l1: 14.8148	test's mae: 14.8148
# Early stopping, best iteration is:
# [2737]	train's l1: 13.3947	train's mae: 13.3947	test's l1: 14.8144	test's mae: 14.8144
#
# ================================================== Fold 8 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7128	train's mae: 15.7128	test's l1: 15.781	test's mae: 15.781
# [400]	train's l1: 14.6885	train's mae: 14.6885	test's l1: 14.9241	test's mae: 14.9241
# [600]	train's l1: 14.4169	train's mae: 14.4169	test's l1: 14.7445	test's mae: 14.7445
# [800]	train's l1: 14.2603	train's mae: 14.2603	test's l1: 14.6802	test's mae: 14.6802
# [1000]	train's l1: 14.1415	train's mae: 14.1415	test's l1: 14.6387	test's mae: 14.6387
# [1200]	train's l1: 14.0383	train's mae: 14.0383	test's l1: 14.6102	test's mae: 14.6102
# [1400]	train's l1: 13.9489	train's mae: 13.9489	test's l1: 14.5918	test's mae: 14.5918
# [1600]	train's l1: 13.8613	train's mae: 13.8613	test's l1: 14.575	test's mae: 14.575
# [1800]	train's l1: 13.778	train's mae: 13.778	test's l1: 14.5625	test's mae: 14.5625
# [2000]	train's l1: 13.6989	train's mae: 13.6989	test's l1: 14.5489	test's mae: 14.5489
# [2200]	train's l1: 13.6231	train's mae: 13.6231	test's l1: 14.5426	test's mae: 14.5426
# [2400]	train's l1: 13.5521	train's mae: 13.5521	test's l1: 14.5351	test's mae: 14.5351
# [2600]	train's l1: 13.4799	train's mae: 13.4799	test's l1: 14.5323	test's mae: 14.5323
# Early stopping, best iteration is:
# [2708]	train's l1: 13.4445	train's mae: 13.4445	test's l1: 14.5263	test's mae: 14.5263
#
# ================================================== Fold 9 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.6923	train's mae: 15.6923	test's l1: 16.0325	test's mae: 16.0325
# [400]	train's l1: 14.6681	train's mae: 14.6681	test's l1: 15.0821	test's mae: 15.0821
# [600]	train's l1: 14.4006	train's mae: 14.4006	test's l1: 14.895	test's mae: 14.895
# [800]	train's l1: 14.2456	train's mae: 14.2456	test's l1: 14.8276	test's mae: 14.8276
# [1000]	train's l1: 14.1337	train's mae: 14.1337	test's l1: 14.7901	test's mae: 14.7901
# [1200]	train's l1: 14.0335	train's mae: 14.0335	test's l1: 14.7598	test's mae: 14.7598
# [1400]	train's l1: 13.9435	train's mae: 13.9435	test's l1: 14.7358	test's mae: 14.7358
# [1600]	train's l1: 13.8593	train's mae: 13.8593	test's l1: 14.7204	test's mae: 14.7204
# [1800]	train's l1: 13.7732	train's mae: 13.7732	test's l1: 14.6985	test's mae: 14.6985
# [2000]	train's l1: 13.6942	train's mae: 13.6942	test's l1: 14.6844	test's mae: 14.6844
# [2200]	train's l1: 13.6176	train's mae: 13.6176	test's l1: 14.6739	test's mae: 14.6739
# [2400]	train's l1: 13.5471	train's mae: 13.5471	test's l1: 14.6681	test's mae: 14.6681
# [2600]	train's l1: 13.4804	train's mae: 13.4804	test's l1: 14.6586	test's mae: 14.6586
# [2800]	train's l1: 13.4137	train's mae: 13.4137	test's l1: 14.6504	test's mae: 14.6504
# [3000]	train's l1: 13.3483	train's mae: 13.3483	test's l1: 14.6437	test's mae: 14.6437
# [3200]	train's l1: 13.2836	train's mae: 13.2836	test's l1: 14.6364	test's mae: 14.6364
# Early stopping, best iteration is:
# [3221]	train's l1: 13.277	train's mae: 13.277	test's l1: 14.6357	test's mae: 14.6357
#
# ================================================== Fold 10 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7211	train's mae: 15.7211	test's l1: 15.7959	test's mae: 15.7959
# [400]	train's l1: 14.7028	train's mae: 14.7028	test's l1: 14.859	test's mae: 14.859
# [600]	train's l1: 14.4338	train's mae: 14.4338	test's l1: 14.6424	test's mae: 14.6424
# [800]	train's l1: 14.2793	train's mae: 14.2793	test's l1: 14.5461	test's mae: 14.5461
# [1000]	train's l1: 14.1612	train's mae: 14.1612	test's l1: 14.4861	test's mae: 14.4861
# [1200]	train's l1: 14.0592	train's mae: 14.0592	test's l1: 14.4478	test's mae: 14.4478
# [1400]	train's l1: 13.9662	train's mae: 13.9662	test's l1: 14.4204	test's mae: 14.4204
# [1600]	train's l1: 13.8815	train's mae: 13.8815	test's l1: 14.4044	test's mae: 14.4044
# [1800]	train's l1: 13.8006	train's mae: 13.8006	test's l1: 14.3929	test's mae: 14.3929
# [2000]	train's l1: 13.7262	train's mae: 13.7262	test's l1: 14.3846	test's mae: 14.3846
# [2200]	train's l1: 13.6488	train's mae: 13.6488	test's l1: 14.377	test's mae: 14.377
# [2400]	train's l1: 13.5756	train's mae: 13.5756	test's l1: 14.3702	test's mae: 14.3702
# [2600]	train's l1: 13.5071	train's mae: 13.5071	test's l1: 14.3664	test's mae: 14.3664
# [2800]	train's l1: 13.4393	train's mae: 13.4393	test's l1: 14.3631	test's mae: 14.3631
# [3000]	train's l1: 13.3745	train's mae: 13.3745	test's l1: 14.3588	test's mae: 14.3588
# Early stopping, best iteration is:
# [2982]	train's l1: 13.3795	train's mae: 13.3795	test's l1: 14.3574	test's mae: 14.3574
# ====================================================================================================
# 0.06401231863897609	0.06454478162173956	0.06451459305333376	0.06331370659478232	0.0648467646956073	0.06376141429335934	0.06323365513255695	0.06440684329638043	0.06395632441649143	0.06511510164034279
# min score: 0.063234
# max score: 0.065115
# median score: 0.064210
# mean score: 0.064171
# [601.58157014 523.6203973  670.76299756 675.84544701 657.47044374
#  613.91615919 640.47453442 569.21022419 674.77810035 589.36076386]

# %%
x, y = train_df[feature_name6], train_df['信用分'].values
x_test = test_df[feature_name6]

model = kf_lgbm(x=x,y=y,x_test=x_test,learning_rate=0.01, 
                stratify=True,
                min_split_gain=1,
                categorical_feature=['用户话费敏感度'],
                boosting_type='gbdt',
                early_stopping_rounds=80,
                fair_c=23, 
                huber_delta=2,
                max_cat_to_onehot=4,
                objective="fair_huber",
                eval_metric="mae",
                subsample_freq=2,
                min_child_samples=20,
                num_leaves=31,
                bagging_fraction=0.8,
                feature_fraction=0.5,
                max_depth=5,
                output_dir=output_dir,
                name='gotcha_lgb5',
                n_estimators=8000)
# Out:
# ================================================== Fold 1 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7732	train's mae: 15.7732	test's l1: 16.0722	test's mae: 16.0722
# [400]	train's l1: 14.6916	train's mae: 14.6916	test's l1: 15.154	test's mae: 15.154
# [600]	train's l1: 14.4138	train's mae: 14.4138	test's l1: 14.9887	test's mae: 14.9887
# [800]	train's l1: 14.2572	train's mae: 14.2572	test's l1: 14.9157	test's mae: 14.9157
# [1000]	train's l1: 14.1433	train's mae: 14.1433	test's l1: 14.8653	test's mae: 14.8653
# [1200]	train's l1: 14.0501	train's mae: 14.0501	test's l1: 14.8334	test's mae: 14.8334
# [1400]	train's l1: 13.9573	train's mae: 13.9573	test's l1: 14.8048	test's mae: 14.8048
# [1600]	train's l1: 13.8753	train's mae: 13.8753	test's l1: 14.7809	test's mae: 14.7809
# [1800]	train's l1: 13.7981	train's mae: 13.7981	test's l1: 14.7639	test's mae: 14.7639
# [2000]	train's l1: 13.7258	train's mae: 13.7258	test's l1: 14.7533	test's mae: 14.7533
# [2200]	train's l1: 13.6554	train's mae: 13.6554	test's l1: 14.74	test's mae: 14.74
# [2400]	train's l1: 13.5883	train's mae: 13.5883	test's l1: 14.7302	test's mae: 14.7302
# [2600]	train's l1: 13.5238	train's mae: 13.5238	test's l1: 14.7227	test's mae: 14.7227
# [2800]	train's l1: 13.4613	train's mae: 13.4613	test's l1: 14.7138	test's mae: 14.7138
# [3000]	train's l1: 13.4019	train's mae: 13.4019	test's l1: 14.7055	test's mae: 14.7055
# [3200]	train's l1: 13.343	train's mae: 13.343	test's l1: 14.6989	test's mae: 14.6989
# [3400]	train's l1: 13.2857	train's mae: 13.2857	test's l1: 14.6935	test's mae: 14.6935
# [3600]	train's l1: 13.2266	train's mae: 13.2266	test's l1: 14.6892	test's mae: 14.6892
# [3800]	train's l1: 13.1724	train's mae: 13.1724	test's l1: 14.6818	test's mae: 14.6818
# [4000]	train's l1: 13.1185	train's mae: 13.1185	test's l1: 14.6771	test's mae: 14.6771
# Early stopping, best iteration is:
# [4037]	train's l1: 13.1085	train's mae: 13.1085	test's l1: 14.6762	test's mae: 14.6762
#
# ================================================== Fold 2 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7878	train's mae: 15.7878	test's l1: 15.9979	test's mae: 15.9979
# [400]	train's l1: 14.724	train's mae: 14.724	test's l1: 14.9619	test's mae: 14.9619
# [600]	train's l1: 14.4445	train's mae: 14.4445	test's l1: 14.7469	test's mae: 14.7469
# [800]	train's l1: 14.2883	train's mae: 14.2883	test's l1: 14.6639	test's mae: 14.6639
# [1000]	train's l1: 14.1683	train's mae: 14.1683	test's l1: 14.6125	test's mae: 14.6125
# [1200]	train's l1: 14.0745	train's mae: 14.0745	test's l1: 14.5886	test's mae: 14.5886
# [1400]	train's l1: 13.9838	train's mae: 13.9838	test's l1: 14.5695	test's mae: 14.5695
# [1600]	train's l1: 13.898	train's mae: 13.898	test's l1: 14.554	test's mae: 14.554
# [1800]	train's l1: 13.8219	train's mae: 13.8219	test's l1: 14.541	test's mae: 14.541
# [2000]	train's l1: 13.7461	train's mae: 13.7461	test's l1: 14.534	test's mae: 14.534
# [2200]	train's l1: 13.6773	train's mae: 13.6773	test's l1: 14.5256	test's mae: 14.5256
# [2400]	train's l1: 13.6107	train's mae: 13.6107	test's l1: 14.5184	test's mae: 14.5184
# [2600]	train's l1: 13.5422	train's mae: 13.5422	test's l1: 14.5146	test's mae: 14.5146
# Early stopping, best iteration is:
# [2594]	train's l1: 13.5443	train's mae: 13.5443	test's l1: 14.5138	test's mae: 14.5138
#
# ================================================== Fold 3 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.8031	train's mae: 15.8031	test's l1: 15.8281	test's mae: 15.8281
# [400]	train's l1: 14.7283	train's mae: 14.7283	test's l1: 14.8896	test's mae: 14.8896
# [600]	train's l1: 14.4525	train's mae: 14.4525	test's l1: 14.7127	test's mae: 14.7127
# [800]	train's l1: 14.2963	train's mae: 14.2963	test's l1: 14.6386	test's mae: 14.6386
# [1000]	train's l1: 14.1778	train's mae: 14.1778	test's l1: 14.5932	test's mae: 14.5932
# [1200]	train's l1: 14.0797	train's mae: 14.0797	test's l1: 14.5682	test's mae: 14.5682
# [1400]	train's l1: 13.9842	train's mae: 13.9842	test's l1: 14.5488	test's mae: 14.5488
# [1600]	train's l1: 13.8968	train's mae: 13.8968	test's l1: 14.5351	test's mae: 14.5351
# [1800]	train's l1: 13.8215	train's mae: 13.8215	test's l1: 14.5257	test's mae: 14.5257
# [2000]	train's l1: 13.7457	train's mae: 13.7457	test's l1: 14.5197	test's mae: 14.5197
# [2200]	train's l1: 13.6732	train's mae: 13.6732	test's l1: 14.511	test's mae: 14.511
# [2400]	train's l1: 13.6057	train's mae: 13.6057	test's l1: 14.5083	test's mae: 14.5083
# [2600]	train's l1: 13.5416	train's mae: 13.5416	test's l1: 14.5036	test's mae: 14.5036
# Early stopping, best iteration is:
# [2618]	train's l1: 13.5358	train's mae: 13.5358	test's l1: 14.5025	test's mae: 14.5025
#
# ================================================== Fold 4 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7645	train's mae: 15.7645	test's l1: 16.1509	test's mae: 16.1509
# [400]	train's l1: 14.6973	train's mae: 14.6973	test's l1: 15.1938	test's mae: 15.1938
# [600]	train's l1: 14.4163	train's mae: 14.4163	test's l1: 15.0079	test's mae: 15.0079
# [800]	train's l1: 14.264	train's mae: 14.264	test's l1: 14.9477	test's mae: 14.9477
# [1000]	train's l1: 14.1472	train's mae: 14.1472	test's l1: 14.9142	test's mae: 14.9142
# [1200]	train's l1: 14.0497	train's mae: 14.0497	test's l1: 14.8888	test's mae: 14.8888
# [1400]	train's l1: 13.9586	train's mae: 13.9586	test's l1: 14.8657	test's mae: 14.8657
# [1600]	train's l1: 13.8725	train's mae: 13.8725	test's l1: 14.8485	test's mae: 14.8485
# [1800]	train's l1: 13.7947	train's mae: 13.7947	test's l1: 14.8367	test's mae: 14.8367
# [2000]	train's l1: 13.7226	train's mae: 13.7226	test's l1: 14.8272	test's mae: 14.8272
# [2200]	train's l1: 13.6504	train's mae: 13.6504	test's l1: 14.818	test's mae: 14.818
# [2400]	train's l1: 13.5813	train's mae: 13.5813	test's l1: 14.8116	test's mae: 14.8116
# [2600]	train's l1: 13.5145	train's mae: 13.5145	test's l1: 14.8088	test's mae: 14.8088
# Early stopping, best iteration is:
# [2536]	train's l1: 13.5339	train's mae: 13.5339	test's l1: 14.8081	test's mae: 14.8081
#
# ================================================== Fold 5 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.789	train's mae: 15.789	test's l1: 15.9445	test's mae: 15.9445
# [400]	train's l1: 14.7184	train's mae: 14.7184	test's l1: 14.9584	test's mae: 14.9584
# [600]	train's l1: 14.439	train's mae: 14.439	test's l1: 14.7446	test's mae: 14.7446
# [800]	train's l1: 14.2867	train's mae: 14.2867	test's l1: 14.6563	test's mae: 14.6563
# [1000]	train's l1: 14.1664	train's mae: 14.1664	test's l1: 14.6011	test's mae: 14.6011
# [1200]	train's l1: 14.0685	train's mae: 14.0685	test's l1: 14.5689	test's mae: 14.5689
# [1400]	train's l1: 13.9815	train's mae: 13.9815	test's l1: 14.5424	test's mae: 14.5424
# [1600]	train's l1: 13.8979	train's mae: 13.8979	test's l1: 14.5199	test's mae: 14.5199
# [1800]	train's l1: 13.8226	train's mae: 13.8226	test's l1: 14.5047	test's mae: 14.5047
# [2000]	train's l1: 13.746	train's mae: 13.746	test's l1: 14.4881	test's mae: 14.4881
# [2200]	train's l1: 13.6738	train's mae: 13.6738	test's l1: 14.4784	test's mae: 14.4784
# [2400]	train's l1: 13.6066	train's mae: 13.6066	test's l1: 14.468	test's mae: 14.468
# [2600]	train's l1: 13.5392	train's mae: 13.5392	test's l1: 14.4616	test's mae: 14.4616
# [2800]	train's l1: 13.478	train's mae: 13.478	test's l1: 14.4583	test's mae: 14.4583
# [3000]	train's l1: 13.4173	train's mae: 13.4173	test's l1: 14.4533	test's mae: 14.4533
# [3200]	train's l1: 13.3557	train's mae: 13.3557	test's l1: 14.4535	test's mae: 14.4535
# Early stopping, best iteration is:
# [3130]	train's l1: 13.3765	train's mae: 13.3765	test's l1: 14.4519	test's mae: 14.4519
#
# ================================================== Fold 6 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7758	train's mae: 15.7758	test's l1: 16.0144	test's mae: 16.0144
# [400]	train's l1: 14.6982	train's mae: 14.6982	test's l1: 15.0956	test's mae: 15.0956
# [600]	train's l1: 14.4175	train's mae: 14.4175	test's l1: 14.9312	test's mae: 14.9312
# [800]	train's l1: 14.2627	train's mae: 14.2627	test's l1: 14.8647	test's mae: 14.8647
# [1000]	train's l1: 14.1458	train's mae: 14.1458	test's l1: 14.8237	test's mae: 14.8237
# [1200]	train's l1: 14.044	train's mae: 14.044	test's l1: 14.793	test's mae: 14.793
# [1400]	train's l1: 13.9543	train's mae: 13.9543	test's l1: 14.7706	test's mae: 14.7706
# [1600]	train's l1: 13.8699	train's mae: 13.8699	test's l1: 14.7557	test's mae: 14.7557
# [1800]	train's l1: 13.7918	train's mae: 13.7918	test's l1: 14.7428	test's mae: 14.7428
# [2000]	train's l1: 13.7178	train's mae: 13.7178	test's l1: 14.7339	test's mae: 14.7339
# [2200]	train's l1: 13.6461	train's mae: 13.6461	test's l1: 14.7295	test's mae: 14.7295
# [2400]	train's l1: 13.5798	train's mae: 13.5798	test's l1: 14.7248	test's mae: 14.7248
# [2600]	train's l1: 13.5124	train's mae: 13.5124	test's l1: 14.7217	test's mae: 14.7217
# [2800]	train's l1: 13.4474	train's mae: 13.4474	test's l1: 14.719	test's mae: 14.719
# [3000]	train's l1: 13.3842	train's mae: 13.3842	test's l1: 14.7182	test's mae: 14.7182
# Early stopping, best iteration is:
# [2962]	train's l1: 13.3958	train's mae: 13.3958	test's l1: 14.7167	test's mae: 14.7167
#
# ================================================== Fold 7 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7702	train's mae: 15.7702	test's l1: 16.2	test's mae: 16.2
# [400]	train's l1: 14.6948	train's mae: 14.6948	test's l1: 15.2117	test's mae: 15.2117
# [600]	train's l1: 14.4144	train's mae: 14.4144	test's l1: 15.0255	test's mae: 15.0255
# [800]	train's l1: 14.2609	train's mae: 14.2609	test's l1: 14.9622	test's mae: 14.9622
# [1000]	train's l1: 14.1453	train's mae: 14.1453	test's l1: 14.9303	test's mae: 14.9303
# [1200]	train's l1: 14.0444	train's mae: 14.0444	test's l1: 14.905	test's mae: 14.905
# [1400]	train's l1: 13.9533	train's mae: 13.9533	test's l1: 14.8839	test's mae: 14.8839
# [1600]	train's l1: 13.8687	train's mae: 13.8687	test's l1: 14.8672	test's mae: 14.8672
# [1800]	train's l1: 13.7879	train's mae: 13.7879	test's l1: 14.8519	test's mae: 14.8519
# [2000]	train's l1: 13.7115	train's mae: 13.7115	test's l1: 14.8442	test's mae: 14.8442
# [2200]	train's l1: 13.6418	train's mae: 13.6418	test's l1: 14.842	test's mae: 14.842
# [2400]	train's l1: 13.5712	train's mae: 13.5712	test's l1: 14.8338	test's mae: 14.8338
# [2600]	train's l1: 13.5081	train's mae: 13.5081	test's l1: 14.8312	test's mae: 14.8312
# Early stopping, best iteration is:
# [2655]	train's l1: 13.4896	train's mae: 13.4896	test's l1: 14.8283	test's mae: 14.8283
#
# ================================================== Fold 8 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7891	train's mae: 15.7891	test's l1: 15.8914	test's mae: 15.8914
# [400]	train's l1: 14.7187	train's mae: 14.7187	test's l1: 14.9621	test's mae: 14.9621
# [600]	train's l1: 14.4361	train's mae: 14.4361	test's l1: 14.7794	test's mae: 14.7794
# [800]	train's l1: 14.2803	train's mae: 14.2803	test's l1: 14.7082	test's mae: 14.7082
# [1000]	train's l1: 14.1627	train's mae: 14.1627	test's l1: 14.6677	test's mae: 14.6677
# [1200]	train's l1: 14.0633	train's mae: 14.0633	test's l1: 14.6415	test's mae: 14.6415
# [1400]	train's l1: 13.9766	train's mae: 13.9766	test's l1: 14.6198	test's mae: 14.6198
# [1600]	train's l1: 13.8935	train's mae: 13.8935	test's l1: 14.6051	test's mae: 14.6051
# [1800]	train's l1: 13.8103	train's mae: 13.8103	test's l1: 14.5955	test's mae: 14.5955
# [2000]	train's l1: 13.7368	train's mae: 13.7368	test's l1: 14.5848	test's mae: 14.5848
# [2200]	train's l1: 13.6625	train's mae: 13.6625	test's l1: 14.5804	test's mae: 14.5804
# Early stopping, best iteration is:
# [2276]	train's l1: 13.6374	train's mae: 13.6374	test's l1: 14.5777	test's mae: 14.5777
#
# ================================================== Fold 9 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7684	train's mae: 15.7684	test's l1: 16.1193	test's mae: 16.1193
# [400]	train's l1: 14.6962	train's mae: 14.6962	test's l1: 15.1106	test's mae: 15.1106
# [600]	train's l1: 14.4162	train's mae: 14.4162	test's l1: 14.9149	test's mae: 14.9149
# [800]	train's l1: 14.2671	train's mae: 14.2671	test's l1: 14.8354	test's mae: 14.8354
# [1000]	train's l1: 14.155	train's mae: 14.155	test's l1: 14.7914	test's mae: 14.7914
# [1200]	train's l1: 14.0561	train's mae: 14.0561	test's l1: 14.7571	test's mae: 14.7571
# [1400]	train's l1: 13.9681	train's mae: 13.9681	test's l1: 14.7325	test's mae: 14.7325
# [1600]	train's l1: 13.8839	train's mae: 13.8839	test's l1: 14.7142	test's mae: 14.7142
# [1800]	train's l1: 13.8053	train's mae: 13.8053	test's l1: 14.6918	test's mae: 14.6918
# [2000]	train's l1: 13.7313	train's mae: 13.7313	test's l1: 14.6774	test's mae: 14.6774
# [2200]	train's l1: 13.6598	train's mae: 13.6598	test's l1: 14.6638	test's mae: 14.6638
# [2400]	train's l1: 13.5938	train's mae: 13.5938	test's l1: 14.6539	test's mae: 14.6539
# Early stopping, best iteration is:
# [2504]	train's l1: 13.5592	train's mae: 13.5592	test's l1: 14.6512	test's mae: 14.6512
#
# ================================================== Fold 10 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 15.7927	train's mae: 15.7927	test's l1: 15.8735	test's mae: 15.8735
# [400]	train's l1: 14.7303	train's mae: 14.7303	test's l1: 14.8803	test's mae: 14.8803
# [600]	train's l1: 14.4562	train's mae: 14.4562	test's l1: 14.6472	test's mae: 14.6472
# [800]	train's l1: 14.3032	train's mae: 14.3032	test's l1: 14.5507	test's mae: 14.5507
# [1000]	train's l1: 14.1873	train's mae: 14.1873	test's l1: 14.4916	test's mae: 14.4916
# [1200]	train's l1: 14.0911	train's mae: 14.0911	test's l1: 14.4521	test's mae: 14.4521
# [1400]	train's l1: 14.001	train's mae: 14.001	test's l1: 14.4216	test's mae: 14.4216
# [1600]	train's l1: 13.9191	train's mae: 13.9191	test's l1: 14.4042	test's mae: 14.4042
# [1800]	train's l1: 13.8404	train's mae: 13.8404	test's l1: 14.3912	test's mae: 14.3912
# [2000]	train's l1: 13.766	train's mae: 13.766	test's l1: 14.3799	test's mae: 14.3799
# [2200]	train's l1: 13.6919	train's mae: 13.6919	test's l1: 14.372	test's mae: 14.372
# [2400]	train's l1: 13.6236	train's mae: 13.6236	test's l1: 14.3662	test's mae: 14.3662
# [2600]	train's l1: 13.5576	train's mae: 13.5576	test's l1: 14.3628	test's mae: 14.3628
# Early stopping, best iteration is:
# [2532]	train's l1: 13.5786	train's mae: 13.5786	test's l1: 14.3623	test's mae: 14.3623
# ====================================================================================================
# 0.06379112693481141	0.06445874247570693	0.06450570033220616	0.06325873900803357	0.06471692384026262	0.06362675439140252	0.06317810603358909	0.06419434891002523	0.06389303978939422	0.06509461764837615
# min score: 0.063178
# max score: 0.065095
# median score: 0.064044
# mean score: 0.064072
# [602.75966182 526.38392308 670.22024409 675.23297907 657.6068463
#  614.98708271 640.065992   568.19006608 675.11483249 587.8092117 ]

# %%
x, y = train_df[feature_name1], train_df['信用分'].values
x_test = test_df[feature_name1]

def fn_transform(x):
    return np.power(1.005, x)
def fn_reverse_transform(x):
    ret = np.log(x)/np.log(1.005)
    return ret

y = fn_transform(y)

model = kf_lgbm(x=x,y=y,x_test=x_test,learning_rate=0.03, 
                fn_reverse_transform=fn_reverse_transform,
                stratify=True, 
                split_seed=8888,
                min_split_gain=1,
                categorical_feature=['用户话费敏感度'],
                boosting_type='gbdt',
                early_stopping_rounds=80,
                fair_c=25, 
                huber_delta=2,
                max_cat_to_onehot=4,
                objective="huber",
                eval_metric="mae",
                subsample_freq=2,
                min_child_samples=20,
                num_leaves=31,
                bagging_fraction=0.8,
                feature_fraction=0.5,
                max_depth=7,
                output_dir=output_dir,
                name='gotcha_lgb6',
                verbose=200,
                n_estimators=8000)
# Out:
# ================================================== Fold 1 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 2.01778	train's mae: 19.4444	test's l1: 2.03708	test's mae: 19.6335
# [400]	train's l1: 1.61963	train's mae: 15.3019	test's l1: 1.65911	test's mae: 15.6763
# [600]	train's l1: 1.54135	train's mae: 14.4329	test's l1: 1.60048	test's mae: 14.9969
# [800]	train's l1: 1.51387	train's mae: 14.1584	test's l1: 1.58761	test's mae: 14.8504
# [1000]	train's l1: 1.49434	train's mae: 13.9724	test's l1: 1.58121	test's mae: 14.7817
# [1200]	train's l1: 1.4803	train's mae: 13.8426	test's l1: 1.57812	test's mae: 14.7482
# [1400]	train's l1: 1.47022	train's mae: 13.7499	test's l1: 1.57622	test's mae: 14.7275
# [1600]	train's l1: 1.46324	train's mae: 13.6857	test's l1: 1.57543	test's mae: 14.7183
# [1800]	train's l1: 1.45834	train's mae: 13.6409	test's l1: 1.57473	test's mae: 14.711
# [2000]	train's l1: 1.45477	train's mae: 13.6083	test's l1: 1.57454	test's mae: 14.7084
# Early stopping, best iteration is:
# [1963]	train's l1: 1.45545	train's mae: 13.6146	test's l1: 1.57448	test's mae: 14.7081
#
# ================================================== Fold 2 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 2.01796	train's mae: 19.4481	test's l1: 2.04113	test's mae: 19.6482
# [400]	train's l1: 1.62087	train's mae: 15.3157	test's l1: 1.65015	test's mae: 15.5654
# [600]	train's l1: 1.54401	train's mae: 14.4636	test's l1: 1.58	test's mae: 14.7706
# [800]	train's l1: 1.51617	train's mae: 14.1826	test's l1: 1.56459	test's mae: 14.6093
# [1000]	train's l1: 1.49697	train's mae: 13.9997	test's l1: 1.55832	test's mae: 14.5479
# [1200]	train's l1: 1.48273	train's mae: 13.8667	test's l1: 1.5549	test's mae: 14.5139
# [1400]	train's l1: 1.47284	train's mae: 13.7749	test's l1: 1.55341	test's mae: 14.4989
# [1600]	train's l1: 1.46575	train's mae: 13.7102	test's l1: 1.55223	test's mae: 14.4871
# [1800]	train's l1: 1.46026	train's mae: 13.6598	test's l1: 1.55162	test's mae: 14.4806
# Early stopping, best iteration is:
# [1763]	train's l1: 1.46116	train's mae: 13.6679	test's l1: 1.55151	test's mae: 14.4796
#
# ================================================== Fold 3 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 2.02111	train's mae: 19.477	test's l1: 2.01072	test's mae: 19.3734
# [400]	train's l1: 1.6218	train's mae: 15.3171	test's l1: 1.62771	test's mae: 15.3953
# [600]	train's l1: 1.54432	train's mae: 14.4591	test's l1: 1.57265	test's mae: 14.7628
# [800]	train's l1: 1.51627	train's mae: 14.1785	test's l1: 1.56167	test's mae: 14.6478
# [1000]	train's l1: 1.49666	train's mae: 13.9931	test's l1: 1.55798	test's mae: 14.6087
# [1200]	train's l1: 1.48236	train's mae: 13.8592	test's l1: 1.55553	test's mae: 14.5832
# [1400]	train's l1: 1.47154	train's mae: 13.7594	test's l1: 1.55469	test's mae: 14.5741
# [1600]	train's l1: 1.46434	train's mae: 13.6941	test's l1: 1.55423	test's mae: 14.569
# Early stopping, best iteration is:
# [1685]	train's l1: 1.46176	train's mae: 13.6702	test's l1: 1.55408	test's mae: 14.5671
#
# ================================================== Fold 4 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 2.01518	train's mae: 19.4196	test's l1: 2.04936	test's mae: 19.7434
# [400]	train's l1: 1.61768	train's mae: 15.2817	test's l1: 1.67206	test's mae: 15.7994
# [600]	train's l1: 1.54096	train's mae: 14.4299	test's l1: 1.60808	test's mae: 15.0705
# [800]	train's l1: 1.51365	train's mae: 14.1518	test's l1: 1.59421	test's mae: 14.9244
# [1000]	train's l1: 1.49413	train's mae: 13.967	test's l1: 1.589	test's mae: 14.8768
# [1200]	train's l1: 1.47902	train's mae: 13.8268	test's l1: 1.58616	test's mae: 14.8508
# [1400]	train's l1: 1.46947	train's mae: 13.7381	test's l1: 1.58517	test's mae: 14.8412
# [1600]	train's l1: 1.46186	train's mae: 13.668	test's l1: 1.58439	test's mae: 14.8341
# [1800]	train's l1: 1.45581	train's mae: 13.6122	test's l1: 1.58353	test's mae: 14.8256
# Early stopping, best iteration is:
# [1822]	train's l1: 1.45537	train's mae: 13.608	test's l1: 1.58344	test's mae: 14.8248
#
# ================================================== Fold 5 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 2.0187	train's mae: 19.4532	test's l1: 2.0264	test's mae: 19.5308
# [400]	train's l1: 1.62048	train's mae: 15.3096	test's l1: 1.646	test's mae: 15.5496
# [600]	train's l1: 1.54409	train's mae: 14.4629	test's l1: 1.58031	test's mae: 14.7918
# [800]	train's l1: 1.51712	train's mae: 14.1924	test's l1: 1.56543	test's mae: 14.6299
# [1000]	train's l1: 1.49772	train's mae: 14.0097	test's l1: 1.55896	test's mae: 14.5627
# [1200]	train's l1: 1.48322	train's mae: 13.8741	test's l1: 1.55554	test's mae: 14.5261
# [1400]	train's l1: 1.47291	train's mae: 13.7782	test's l1: 1.55356	test's mae: 14.5045
# [1600]	train's l1: 1.46568	train's mae: 13.7105	test's l1: 1.55256	test's mae: 14.4939
# [1800]	train's l1: 1.46027	train's mae: 13.6612	test's l1: 1.55218	test's mae: 14.4899
# Early stopping, best iteration is:
# [1903]	train's l1: 1.45822	train's mae: 13.6422	test's l1: 1.55184	test's mae: 14.4867
#
# ================================================== Fold 6 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 2.01537	train's mae: 19.4257	test's l1: 2.05167	test's mae: 19.7503
# [400]	train's l1: 1.61988	train's mae: 15.3058	test's l1: 1.66571	test's mae: 15.7163
# [600]	train's l1: 1.54268	train's mae: 14.4473	test's l1: 1.59926	test's mae: 14.967
# [800]	train's l1: 1.51454	train's mae: 14.1623	test's l1: 1.58543	test's mae: 14.8288
# [1000]	train's l1: 1.49505	train's mae: 13.977	test's l1: 1.57948	test's mae: 14.7722
# [1200]	train's l1: 1.47992	train's mae: 13.8357	test's l1: 1.57658	test's mae: 14.7461
# [1400]	train's l1: 1.46899	train's mae: 13.7338	test's l1: 1.57515	test's mae: 14.7335
# [1600]	train's l1: 1.46131	train's mae: 13.6636	test's l1: 1.57445	test's mae: 14.7268
# [1800]	train's l1: 1.45523	train's mae: 13.6079	test's l1: 1.57401	test's mae: 14.7227
# Early stopping, best iteration is:
# [1858]	train's l1: 1.45405	train's mae: 13.5969	test's l1: 1.57384	test's mae: 14.7216
#
# ================================================== Fold 7 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 2.01371	train's mae: 19.4118	test's l1: 2.06525	test's mae: 19.8534
# [400]	train's l1: 1.61794	train's mae: 15.2905	test's l1: 1.67921	test's mae: 15.8172
# [600]	train's l1: 1.5401	train's mae: 14.4266	test's l1: 1.6155	test's mae: 15.0901
# [800]	train's l1: 1.51183	train's mae: 14.1425	test's l1: 1.60294	test's mae: 14.9587
# [1000]	train's l1: 1.49277	train's mae: 13.9604	test's l1: 1.59847	test's mae: 14.9152
# [1200]	train's l1: 1.47804	train's mae: 13.8225	test's l1: 1.5962	test's mae: 14.894
# [1400]	train's l1: 1.46785	train's mae: 13.7277	test's l1: 1.59473	test's mae: 14.8799
# [1600]	train's l1: 1.46125	train's mae: 13.6667	test's l1: 1.59411	test's mae: 14.8742
# [1800]	train's l1: 1.4561	train's mae: 13.6193	test's l1: 1.59377	test's mae: 14.8708
# Early stopping, best iteration is:
# [1817]	train's l1: 1.45566	train's mae: 13.6153	test's l1: 1.59357	test's mae: 14.869
#
# ================================================== Fold 8 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 2.01806	train's mae: 19.4476	test's l1: 2.02472	test's mae: 19.5037
# [400]	train's l1: 1.62033	train's mae: 15.3056	test's l1: 1.64487	test's mae: 15.547
# [600]	train's l1: 1.54284	train's mae: 14.4453	test's l1: 1.5838	test's mae: 14.8558
# [800]	train's l1: 1.51553	train's mae: 14.172	test's l1: 1.57087	test's mae: 14.7205
# [1000]	train's l1: 1.4962	train's mae: 13.9893	test's l1: 1.56541	test's mae: 14.6648
# [1200]	train's l1: 1.48109	train's mae: 13.8492	test's l1: 1.56248	test's mae: 14.6352
# [1400]	train's l1: 1.47073	train's mae: 13.7538	test's l1: 1.56176	test's mae: 14.6274
# Early stopping, best iteration is:
# [1380]	train's l1: 1.47174	train's mae: 13.7629	test's l1: 1.56172	test's mae: 14.6272
#
# ================================================== Fold 9 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 2.01663	train's mae: 19.4323	test's l1: 2.03385	test's mae: 19.5925
# [400]	train's l1: 1.61948	train's mae: 15.2961	test's l1: 1.6544	test's mae: 15.6441
# [600]	train's l1: 1.54244	train's mae: 14.4412	test's l1: 1.59224	test's mae: 14.9433
# [800]	train's l1: 1.51528	train's mae: 14.1678	test's l1: 1.57818	test's mae: 14.7947
# [1000]	train's l1: 1.49634	train's mae: 13.9894	test's l1: 1.57319	test's mae: 14.7432
# [1200]	train's l1: 1.48144	train's mae: 13.8512	test's l1: 1.56993	test's mae: 14.7099
# [1400]	train's l1: 1.4711	train's mae: 13.7557	test's l1: 1.56797	test's mae: 14.69
# [1600]	train's l1: 1.4643	train's mae: 13.6928	test's l1: 1.56735	test's mae: 14.6837
# [1800]	train's l1: 1.4592	train's mae: 13.6456	test's l1: 1.56665	test's mae: 14.6765
# [2000]	train's l1: 1.45541	train's mae: 13.6108	test's l1: 1.56631	test's mae: 14.6729
# Early stopping, best iteration is:
# [1955]	train's l1: 1.45588	train's mae: 13.6151	test's l1: 1.56624	test's mae: 14.6725
#
# ================================================== Fold 10 ==================================================
# Training until validation scores don't improve for 80 rounds.
# [200]	train's l1: 2.01917	train's mae: 19.4582	test's l1: 2.02331	test's mae: 19.4932
# [400]	train's l1: 1.62234	train's mae: 15.3266	test's l1: 1.63425	test's mae: 15.426
# [600]	train's l1: 1.54544	train's mae: 14.472	test's l1: 1.56887	test's mae: 14.6973
# [800]	train's l1: 1.51807	train's mae: 14.197	test's l1: 1.55306	test's mae: 14.5334
# [1000]	train's l1: 1.49887	train's mae: 14.0162	test's l1: 1.54596	test's mae: 14.4617
# [1200]	train's l1: 1.4845	train's mae: 13.8819	test's l1: 1.5427	test's mae: 14.4288
# [1400]	train's l1: 1.47477	train's mae: 13.7918	test's l1: 1.54117	test's mae: 14.4126
# [1600]	train's l1: 1.46741	train's mae: 13.724	test's l1: 1.54027	test's mae: 14.4028
# Early stopping, best iteration is:
# [1656]	train's l1: 1.46588	train's mae: 13.7101	test's l1: 1.5401	test's mae: 14.4009
# ====================================================================================================
# 0.0636598661920948	0.0645997070580731	0.0642362533897782	0.06318981433231707	0.06457062562234571	0.06360620675050753	0.06301191117589236	0.0639909582755511	0.06380221102180222	0.06492943097945296
# min score: 0.063012
# max score: 0.064929
# median score: 0.063897
# mean score: 0.063960
# [601.81336154 532.74852888 670.20251737 674.93737869 657.62633074
#  612.33610717 642.37374802 573.37828285 673.12764407 589.39562007]
